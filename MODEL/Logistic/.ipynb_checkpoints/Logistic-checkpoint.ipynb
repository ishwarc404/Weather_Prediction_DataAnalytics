# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import statsmodels.api as sm
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %%
#44009 and 44065 were the two buoys lying right on the trajectory of the hurricane 
#so we decided to use them to analyse the data further
df_b7_init = pd.read_csv('/Users/shreyabanerjee/DA_proj/clean_csvs/44009_clean.csv')
df_b8_init = pd.read_csv('/Users/shreyabanerjee/DA_proj/clean_csvs/44065_clean.csv')

# %%
#A function to visualise the variation of pressure and windspeed together 
def plot_df(df, x,y1, y2, title, xlabel,data ,dpi=100):
    fig = plt.figure(figsize=(15,8))
    ax1 = fig.add_subplot(111)
    ax1.plot(x, y1)
    ax1.set_ylabel('Windspeed')
    ax1.set_xlabel(xlabel)
    ax1.set_title(title)
    plt.xticks(rotation=90)
    ax2 = ax1.twinx()
    ax2.plot(x, y2, 'r-')
    ax2.set_ylabel('Pressure', color='r')
    if(data=='year'):
        ax2.xaxis.set_major_formatter(plt.NullFormatter())
        ax1.xaxis.set_major_formatter(plt.NullFormatter())
    for tl in ax2.get_yticklabels():
        tl.set_color('r')
        
    plt.tight_layout()

# %%
#Since buoy ID does not contribute to any prediction and is same throughout the csv, we won't keep it for analysis
keep_col = ['day','month','datetime','waveperiod','waveheight','WindDir','windspeed','pressure','possibility','hurrthreat']
df_b7 = df_b7_init[keep_col]
df_b8=df_b8_init[keep_col]

# %%
rs_09 = df_b7.loc[ (df_b7['month']==8)] #& ( (df_b7['day']==27) | (df_b7['day']==28) | (df_b7['day']==29) )]rs_09['date'] = rs_09['datetime'].astype('datetime64[ns]')
rs_09['date'] = rs_09['datetime'].astype('datetime64[ns]')
rs_09.head()
plot_df(rs_09, x=rs_09.datetime,y1=rs_09.windspeed, y2=rs_09.pressure, title='Presure and windspeed variations throughout the year in buoy 44009',xlabel="Date",data="year")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rs_65 = df_b8.loc[ (df_b8['month']==8)]# & ( (df_b8['day']==27) | (df_b8['day']==28) | (df_b8['day']==29) )]
rs_65['date'] = rs_65['datetime'].astype('datetime64[ns]')
rs_65.head()
plot_df(rs_65, x=rs_65.datetime,y1=rs_65.windspeed, y2=rs_65.pressure, title='Presure and windspeed variations throughout the year in buoy 44009',xlabel="Date",data="year")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#the possibility coulmn has value 1 if the pressure is less than 1000, which seems to be the threshold value for
#indication of hurricane

x=df_b7['pressure']
y1=df_b7['possibility']
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(111)
ax1.plot(x, y1)
ax1.set_ylabel('Possibilty of hurricane')
ax1.set_xlabel('Pressure(in hPA)')
# Out:
# Text(0.5, 0, 'Pressure(in hPA)')

# %% [markdown]
# Since we need to predict if occurence of hurricane is possible or not given these readings, logistic regression seems to be a good choice to predict the outcome variable, i.e, 'possibility'.

# %%
y1.value_counts()
# Out:
# 0.0    8514
# 1.0     190
# Name: possibility, dtype: int64

# %%
sns.countplot(x='possibility',data=df_b7)
plt.show()

# %%
count_no_sub = len(y1[y1==0])
count_sub = len(y1[y1==1])
pct_of_no_sub = count_no_sub/(count_no_sub+count_sub)
print("Percentage of instances with no occurence of hurricane ", pct_of_no_sub*100)
pct_of_sub = count_sub/(count_no_sub+count_sub)
print("Percentage of instances where hurricane actually occured", pct_of_sub*100)
# Out:
# Percentage of instances with no occurence of hurricane  97.81709558823529
# Percentage of instances where hurricane actually occured 2.1829044117647056

# %% [markdown]
# INFERENCE:
# There is a gross imbalance of data. There are very small number of intances of actual interest.

# %% [markdown]
# OBSERVATIONS SO FAR:
# Pressure and windspeed are the features most affected by the occurence of a hurricane.
# There are a very few instances of interest.

# %% [markdown]
# Let us try to upsample the no-hurricane data using the SMOTE algorithm(Synthetic Minority Oversampling Technique).
# A few facts about SMOTE:
# 1)Works by creating synthetic samples from the minor class (no-subscription) instead of creating copies.
# 2)Randomly choosing one of the k-nearest-neighbors and using it to create a similar, but randomly tweaked, new observations.
#
# We will over-sampled only on the training data, because by oversampling only on the training data, none of the information in the test data is being used to create synthetic observations, therefore, no information will bleed from test data into the model training.

# %%
#taking a set of possible predictor variables
keep_col = ['day','month','waveperiod','waveheight','WindDir','windspeed','pressure']

X = df_b7[keep_col]
y = df_b7['possibility']

os = SMOTE(random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

columns = X_train.columns

os_data_X,os_data_y=os.fit_sample(X_train, y_train)

os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['possibility'])
# we can Check the numbers of our data
print("Length of oversampled data is ",len(os_data_X))
print("Number of no hurricane (possibility=0) readings in oversampled data",len(os_data_y[os_data_y['possibility']==0]))
print("Number of hurricane occurence readings",len(os_data_y[os_data_y['possibility']==1]))
print("Proportion of no hurricane data in oversampled data is ",len(os_data_y[os_data_y['possibility']==0])/len(os_data_X))
print("Proportion of hurricane data in oversampled data is ",len(os_data_y[os_data_y['possibility']==1])/len(os_data_X))
# Out:
# Length of oversampled data is  11904
# Number of no hurricane (possibility=0) readings in oversampled data 5952
# Number of hurricane occurence readings 5952
# Proportion of no hurricane data in oversampled data is  0.5
# Proportion of hurricane data in oversampled data is  0.5

# %% [markdown]
# Now, the question arises , which features to take as predictor variables ?
# Irrelevant or partially relevant features can negatively impact model performance.
# The main problem is that factors like day, month, hour and minute obviously do not affect the occurence of a hurricane.
# Features like pressure, windspeed and waveheight might change drastically n such events.
# Our previous visualisations and conclusions support this fact.
# Let's just try building a model using these features.

# %%
keep_col = ['windspeed','pressure','waveheight']
df_b7_logit = os_data_X[keep_col]
y1=os_data_y['possibility']

# %%
X_train, x_test, y_train, y_test = train_test_split(df_b7_logit,y1,test_size=0.3, random_state=0)

# %%
logreg = LogisticRegression()
result=logreg.fit(X_train,y_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.

# %%
#keep_col_new=['pressure']
#new_x= df_b7_init[keep_col_new]
#y1=df_b7_init['hurrthreat']
#X_t, X_tes, y_t, y_tes = train_test_split(new_x, y1, test_size=0.3, random_state=0)

#model.fit(X_t, y_t)
y_pred = logreg.predict(x_test)
x_test.head()
#X_tes.iloc[3]
for i in range(len(x_test)):
    if(y_pred[i]==1):
        print("%s, Predicted=%s" % (x_test.iloc[i], y_pred[i]))
# Out:
# windspeed       7.836069
# pressure      999.000205
# waveheight      1.737829
# Name: 8745, dtype: float64, Predicted=1.0
# windspeed       8.397315
# pressure      999.248657
# waveheight      1.700405
# Name: 7131, dtype: float64, Predicted=1.0
# windspeed      16.045903
# pressure      996.085424
# waveheight      9.000000
# Name: 9020, dtype: float64, Predicted=1.0
# windspeed      14.714093
# pressure      981.612299
# waveheight      3.758725
# Name: 6169, dtype: float64, Predicted=1.0
# windspeed       9.578542
# pressure      998.991845
# waveheight      2.816696
# Name: 10760, dtype: float64, Predicted=1.0
# windspeed      10.692800
# pressure      998.634585
# waveheight      2.184006
# Name: 8018, dtype: float64, Predicted=1.0
# windspeed       8.667915
# pressure      999.006148
# waveheight      1.518156
# Name: 11676, dtype: float64, Predicted=1.0
# windspeed      13.567459
# pressure      997.102376
# waveheight      2.883407
# Name: 9157, dtype: float64, Predicted=1.0
# windspeed       7.729769
# pressure      996.279640
# waveheight      1.806637
# Name: 11026, dtype: float64, Predicted=1.0
# windspeed       8.807697
# pressure      999.496151
# waveheight      1.563212
# Name: 6646, dtype: float64, Predicted=1.0
# windspeed      11.317970
# pressure      996.711370
# waveheight      2.843953
# Name: 8305, dtype: float64, Predicted=1.0
# windspeed       11.20
# pressure      1025.80
# waveheight       1.53
# Name: 5283, dtype: float64, Predicted=1.0
# windspeed      14.084112
# pressure      994.642987
# waveheight      3.851683
# Name: 9377, dtype: float64, Predicted=1.0
# windspeed       11.9
# pressure      1016.7
# waveheight       2.6
# Name: 4429, dtype: float64, Predicted=1.0
# windspeed      16.770231
# pressure      990.506500
# waveheight      2.940188
# Name: 10701, dtype: float64, Predicted=1.0
# windspeed      12.942544
# pressure      994.169756
# waveheight      3.025105
# Name: 11208, dtype: float64, Predicted=1.0
# windspeed      15.516503
# pressure      997.241435
# waveheight      8.848665
# Name: 10951, dtype: float64, Predicted=1.0
# windspeed       9.069715
# pressure      999.084690
# waveheight      1.609610
# Name: 7868, dtype: float64, Predicted=1.0
# windspeed      11.540791
# pressure      995.281583
# waveheight      2.804211
# Name: 6343, dtype: float64, Predicted=1.0
# windspeed       8.650193
# pressure      999.409961
# waveheight      2.281526
# Name: 11248, dtype: float64, Predicted=1.0
# windspeed      13.613574
# pressure      999.337691
# waveheight      2.885580
# Name: 7492, dtype: float64, Predicted=1.0
# windspeed      14.373133
# pressure      997.196004
# waveheight      3.548211
# Name: 10150, dtype: float64, Predicted=1.0
# windspeed       4.734252
# pressure      995.337008
# waveheight      9.000000
# Name: 8300, dtype: float64, Predicted=1.0
# windspeed      14.472537
# pressure      999.845073
# waveheight      2.968169
# Name: 7352, dtype: float64, Predicted=1.0
# windspeed       7.963623
# pressure      998.136400
# waveheight      9.000000
# Name: 8406, dtype: float64, Predicted=1.0
# windspeed      14.473711
# pressure      991.798287
# waveheight      5.418455
# Name: 7229, dtype: float64, Predicted=1.0
# windspeed      10.316387
# pressure      998.257643
# waveheight      2.275156
# Name: 10989, dtype: float64, Predicted=1.0
# windspeed       8.282813
# pressure      999.191407
# waveheight      2.001926
# Name: 7710, dtype: float64, Predicted=1.0
# windspeed       9.2
# pressure      995.7
# waveheight      9.0
# Name: 3839, dtype: float64, Predicted=1.0
# windspeed       11.80
# pressure      1018.10
# waveheight       1.53
# Name: 5385, dtype: float64, Predicted=1.0
# windspeed      14.414222
# pressure      996.837245
# waveheight      9.000000
# Name: 6321, dtype: float64, Predicted=1.0
# windspeed       9.535117
# pressure      999.170234
# waveheight      4.118996
# Name: 7031, dtype: float64, Predicted=1.0
# windspeed      10.607760
# pressure      994.636428
# waveheight      2.541552
# Name: 8588, dtype: float64, Predicted=1.0
# windspeed       8.226321
# pressure      994.933550
# waveheight      1.079805
# Name: 10737, dtype: float64, Predicted=1.0
# windspeed       8.472733
# pressure      997.340604
# waveheight      2.140000
# Name: 8166, dtype: float64, Predicted=1.0
# windspeed      11.302079
# pressure      998.790629
# waveheight      9.000000
# Name: 10977, dtype: float64, Predicted=1.0
# windspeed       10.5
# pressure      1024.8
# waveheight       9.0
# Name: 521, dtype: float64, Predicted=1.0
# windspeed      16.775913
# pressure      969.994116
# waveheight      5.909755
# Name: 8407, dtype: float64, Predicted=1.0
# windspeed       7.890148
# pressure      997.280788
# waveheight      2.015862
# Name: 9699, dtype: float64, Predicted=1.0
# windspeed      12.906443
# pressure      994.208056
# waveheight      2.171404
# Name: 6803, dtype: float64, Predicted=1.0
# windspeed       8.393033
# pressure      999.041978
# waveheight      1.974539
# Name: 10358, dtype: float64, Predicted=1.0
# windspeed       8.266890
# pressure      999.604327
# waveheight      1.015042
# Name: 7368, dtype: float64, Predicted=1.0
# windspeed      14.374419
# pressure      991.822439
# waveheight      5.346267
# Name: 11511, dtype: float64, Predicted=1.0
# windspeed       9.854355
# pressure      999.299330
# waveheight      2.611742
# Name: 6263, dtype: float64, Predicted=1.0
# windspeed       6.204213
# pressure      991.019894
# waveheight      3.636776
# Name: 6881, dtype: float64, Predicted=1.0
# windspeed      13.778967
# pressure      984.669695
# waveheight      3.593002
# Name: 8790, dtype: float64, Predicted=1.0
# windspeed       8.039472
# pressure      999.069736
# waveheight      2.642723
# Name: 10850, dtype: float64, Predicted=1.0
# windspeed       8.739648
# pressure      999.124525
# waveheight      1.577172
# Name: 10685, dtype: float64, Predicted=1.0
# windspeed       10.60
# pressure      1007.70
# waveheight       1.86
# Name: 1091, dtype: float64, Predicted=1.0
# windspeed      12.266423
# pressure      992.866240
# waveheight      4.336677
# Name: 7317, dtype: float64, Predicted=1.0
# windspeed       7.800374
# pressure      997.499520
# waveheight      5.166024
# Name: 7667, dtype: float64, Predicted=1.0
# windspeed      12.965169
# pressure      997.198074
# waveheight      2.733435
# Name: 7502, dtype: float64, Predicted=1.0
# windspeed        9.20
# pressure      1013.60
# waveheight       2.01
# Name: 4866, dtype: float64, Predicted=1.0
# windspeed       9.799960
# pressure      996.227767
# waveheight      5.042685
# Name: 9199, dtype: float64, Predicted=1.0
# windspeed       9.174370
# pressure      999.121008
# waveheight      1.797794
# Name: 7575, dtype: float64, Predicted=1.0
# windspeed       10.30
# pressure      1003.60
# waveheight       1.73
# Name: 1334, dtype: float64, Predicted=1.0
# windspeed       10.70
# pressure      1020.30
# waveheight       1.45
# Name: 1143, dtype: float64, Predicted=1.0
# windspeed       10.80
# pressure      1010.00
# waveheight       1.65
# Name: 1738, dtype: float64, Predicted=1.0
# windspeed       7.462560
# pressure      998.807993
# waveheight      2.902025
# Name: 10579, dtype: float64, Predicted=1.0
# windspeed      11.072601
# pressure      998.836300
# waveheight      4.674800
# Name: 9362, dtype: float64, Predicted=1.0
# windspeed      11.832641
# pressure      993.523739
# waveheight      3.197359
# Name: 8051, dtype: float64, Predicted=1.0
# windspeed      11.939383
# pressure      998.789640
# waveheight      1.742535
# Name: 7767, dtype: float64, Predicted=1.0
# windspeed       9.464038
# pressure      994.796657
# waveheight      1.492045
# Name: 8069, dtype: float64, Predicted=1.0
# windspeed      14.233414
# pressure      995.961824
# waveheight      3.694915
# Name: 11769, dtype: float64, Predicted=1.0
# windspeed       8.087307
# pressure      997.311149
# waveheight      1.740154
# Name: 11526, dtype: float64, Predicted=1.0
# windspeed       8.962689
# pressure      998.537989
# waveheight      1.500289
# Name: 10708, dtype: float64, Predicted=1.0
# windspeed        9.00
# pressure      1011.40
# waveheight       1.67
# Name: 5053, dtype: float64, Predicted=1.0
# windspeed       8.542317
# pressure      997.354063
# waveheight      2.849421
# Name: 8710, dtype: float64, Predicted=1.0
# windspeed      15.759651
# pressure      997.112271
# waveheight      3.592893
# Name: 10693, dtype: float64, Predicted=1.0
# windspeed      15.866291
# pressure      991.649070
# waveheight      9.000000
# Name: 11205, dtype: float64, Predicted=1.0
# windspeed      16.728366
# pressure      967.790330
# waveheight      6.070954
# Name: 7283, dtype: float64, Predicted=1.0
# windspeed      10.453124
# pressure      996.514642
# waveheight      1.962816
# Name: 10420, dtype: float64, Predicted=1.0
# windspeed       9.50
# pressure      996.90
# waveheight      2.23
# Name: 5761, dtype: float64, Predicted=1.0
# windspeed       9.090659
# pressure      999.254946
# waveheight      1.803654
# Name: 7302, dtype: float64, Predicted=1.0
# windspeed      14.147136
# pressure      991.842044
# waveheight      3.088706
# Name: 10043, dtype: float64, Predicted=1.0
# windspeed       7.483593
# pressure      997.028623
# waveheight      2.173665
# Name: 9138, dtype: float64, Predicted=1.0
# windspeed      12.014346
# pressure      992.401435
# waveheight      3.697183
# Name: 6426, dtype: float64, Predicted=1.0
# windspeed       9.785469
# pressure      996.548890
# waveheight      2.808883
# Name: 11339, dtype: float64, Predicted=1.0
# windspeed      15.385032
# pressure      999.491155
# waveheight      3.022381
# Name: 8360, dtype: float64, Predicted=1.0
# windspeed      14.470063
# pressure      999.398552
# waveheight      3.055507
# Name: 8283, dtype: float64, Predicted=1.0
# windspeed      13.145194
# pressure      994.404089
# waveheight      6.700572
# Name: 11474, dtype: float64, Predicted=1.0
# windspeed      10.598630
# pressure      998.904110
# waveheight      1.775208
# Name: 8648, dtype: float64, Predicted=1.0
# windspeed      13.067573
# pressure      998.192816
# waveheight      2.098563
# Name: 6839, dtype: float64, Predicted=1.0
# windspeed       9.034877
# pressure      996.873951
# waveheight      1.798698
# Name: 11115, dtype: float64, Predicted=1.0
# windspeed      10.913555
# pressure      998.690504
# waveheight      2.211153
# Name: 7159, dtype: float64, Predicted=1.0
# windspeed       8.370646
# pressure      998.333997
# waveheight      2.811848
# Name: 6116, dtype: float64, Predicted=1.0
# windspeed       9.048273
# pressure      996.267826
# waveheight      2.317702
# Name: 9951, dtype: float64, Predicted=1.0
# windspeed       8.412767
# pressure      995.230850
# waveheight      1.994501
# Name: 10987, dtype: float64, Predicted=1.0
# windspeed       10.4
# pressure      1009.3
# waveheight       9.0
# Name: 823, dtype: float64, Predicted=1.0
# windspeed       8.706724
# pressure      998.466810
# waveheight      1.474306
# Name: 8773, dtype: float64, Predicted=1.0
# windspeed      15.158714
# pressure      994.936203
# waveheight      3.115871
# Name: 7243, dtype: float64, Predicted=1.0
# windspeed      13.073350
# pressure      992.602690
# waveheight      8.628847
# Name: 9003, dtype: float64, Predicted=1.0
# windspeed      15.486162
# pressure      969.685710
# waveheight      4.698550
# Name: 7269, dtype: float64, Predicted=1.0
# windspeed      15.289338
# pressure      995.583285
# waveheight      3.954554
# Name: 7072, dtype: float64, Predicted=1.0
# windspeed      14.600261
# pressure      996.945170
# waveheight      9.000000
# Name: 7212, dtype: float64, Predicted=1.0
# windspeed       7.671327
# pressure      996.188731
# waveheight      1.715079
# Name: 7336, dtype: float64, Predicted=1.0
# windspeed       8.897951
# pressure      998.543279
# waveheight      1.443713
# Name: 10255, dtype: float64, Predicted=1.0
# windspeed       8.711627
# pressure      998.379617
# waveheight      1.514754
# Name: 8309, dtype: float64, Predicted=1.0
# windspeed      14.816190
# pressure      992.967212
# waveheight      2.780342
# Name: 6379, dtype: float64, Predicted=1.0
# windspeed      13.881334
# pressure      994.948151
# waveheight      9.000000
# Name: 10019, dtype: float64, Predicted=1.0
# windspeed       8.178277
# pressure      995.321878
# waveheight      2.004469
# Name: 9254, dtype: float64, Predicted=1.0
# windspeed       8.809082
# pressure      999.211691
# waveheight      1.827392
# Name: 11073, dtype: float64, Predicted=1.0
# windspeed        9.70
# pressure      1013.70
# waveheight       0.85
# Name: 256, dtype: float64, Predicted=1.0
# windspeed      14.604093
# pressure      998.313446
# waveheight      5.996908
# Name: 9728, dtype: float64, Predicted=1.0
# windspeed       7.593705
# pressure      997.576574
# waveheight      2.151713
# Name: 7586, dtype: float64, Predicted=1.0
# windspeed      14.710677
# pressure      998.259247
# waveheight      6.458755
# Name: 8822, dtype: float64, Predicted=1.0
# windspeed       11.00
# pressure      1022.50
# waveheight       1.49
# Name: 5998, dtype: float64, Predicted=1.0
# windspeed      10.072442
# pressure      999.356184
# waveheight      2.287845
# Name: 8640, dtype: float64, Predicted=1.0
# windspeed      11.113585
# pressure      998.856792
# waveheight      6.066208
# Name: 8880, dtype: float64, Predicted=1.0
# windspeed       8.309733
# pressure      999.204866
# waveheight      1.931037
# Name: 6153, dtype: float64, Predicted=1.0
# windspeed      16.042972
# pressure      995.270683
# waveheight      3.274157
# Name: 8505, dtype: float64, Predicted=1.0
# windspeed      13.033698
# pressure      999.191804
# waveheight      3.510073
# Name: 9767, dtype: float64, Predicted=1.0
# windspeed      14.480160
# pressure      996.551198
# waveheight      8.682060
# Name: 11463, dtype: float64, Predicted=1.0
# windspeed       7.847198
# pressure      996.797238
# waveheight      2.213331
# Name: 6726, dtype: float64, Predicted=1.0
# windspeed      15.083386
# pressure      992.642484
# waveheight      2.841274
# Name: 10294, dtype: float64, Predicted=1.0
# windspeed      14.909928
# pressure      996.977663
# waveheight      4.055688
# Name: 9904, dtype: float64, Predicted=1.0
# windspeed      10.064399
# pressure      998.133973
# waveheight      1.958124
# Name: 11462, dtype: float64, Predicted=1.0
# windspeed       9.265548
# pressure      993.838703
# waveheight      2.444921
# Name: 6402, dtype: float64, Predicted=1.0
# windspeed      16.427959
# pressure      994.854355
# waveheight      9.000000
# Name: 11265, dtype: float64, Predicted=1.0
# windspeed      14.161456
# pressure      996.022912
# waveheight      3.938766
# Name: 6505, dtype: float64, Predicted=1.0
# windspeed       8.670434
# pressure      995.525327
# waveheight      3.107691
# Name: 6652, dtype: float64, Predicted=1.0
# windspeed       7.300454
# pressure      999.330413
# waveheight      3.135306
# Name: 9101, dtype: float64, Predicted=1.0
# windspeed      10.658910
# pressure      999.781203
# waveheight      2.265140
# Name: 7569, dtype: float64, Predicted=1.0
# windspeed      15.964267
# pressure      995.782265
# waveheight      3.362700
# Name: 6193, dtype: float64, Predicted=1.0
# windspeed      10.928232
# pressure      995.057651
# waveheight      2.713998
# Name: 8643, dtype: float64, Predicted=1.0
# windspeed      13.106753
# pressure      999.507759
# waveheight      3.114459
# Name: 6249, dtype: float64, Predicted=1.0
# windspeed      14.182477
# pressure      996.903621
# waveheight      7.269514
# Name: 10653, dtype: float64, Predicted=1.0
# windspeed       4.762275
# pressure      995.449099
# waveheight      9.000000
# Name: 7702, dtype: float64, Predicted=1.0
# windspeed      11.671420
# pressure      993.659283
# waveheight      7.046357
# Name: 6403, dtype: float64, Predicted=1.0
# windspeed       7.880407
# pressure      995.803051
# waveheight      1.398828
# Name: 9794, dtype: float64, Predicted=1.0
# windspeed        9.00
# pressure      1003.30
# waveheight       2.65
# Name: 1656, dtype: float64, Predicted=1.0
# windspeed      14.204409
# pressure      996.415174
# waveheight      7.855615
# Name: 10375, dtype: float64, Predicted=1.0
# windspeed       9.207554
# pressure      999.282352
# waveheight      2.074788
# Name: 7773, dtype: float64, Predicted=1.0
# windspeed       8.000409
# pressure      996.604065
# waveheight      1.547765
# Name: 7563, dtype: float64, Predicted=1.0
# windspeed       7.161834
# pressure      998.731103
# waveheight      2.964374
# Name: 11392, dtype: float64, Predicted=1.0
# windspeed       10.60
# pressure      1025.20
# waveheight       1.77
# Name: 2760, dtype: float64, Predicted=1.0
# windspeed        9.0
# pressure      1012.1
# waveheight       9.0
# Name: 1218, dtype: float64, Predicted=1.0
# windspeed      14.238077
# pressure      997.209424
# waveheight      6.742236
# Name: 7969, dtype: float64, Predicted=1.0
# windspeed      10.894001
# pressure      996.905999
# waveheight      1.925342
# Name: 11158, dtype: float64, Predicted=1.0
# windspeed      14.857192
# pressure      999.179250
# waveheight      3.106356
# Name: 10422, dtype: float64, Predicted=1.0
# windspeed       11.80
# pressure      1014.90
# waveheight       2.18
# Name: 4153, dtype: float64, Predicted=1.0
# windspeed      15.809763
# pressure      992.817051
# waveheight      3.779512
# Name: 7637, dtype: float64, Predicted=1.0
# windspeed      14.100000
# pressure      994.343021
# waveheight      2.715681
# Name: 11435, dtype: float64, Predicted=1.0
# windspeed       9.304910
# pressure      999.774718
# waveheight      2.515547
# Name: 8280, dtype: float64, Predicted=1.0
# windspeed       9.543730
# pressure      997.493545
# waveheight      2.004051
# Name: 11844, dtype: float64, Predicted=1.0
# windspeed       5.220256
# pressure      995.463701
# waveheight      8.070893
# Name: 6481, dtype: float64, Predicted=1.0
# windspeed      10.666548
# pressure      995.940435
# waveheight      2.849615
# Name: 6165, dtype: float64, Predicted=1.0
# windspeed      15.443481
# pressure      999.210125
# waveheight      3.112760
# Name: 6248, dtype: float64, Predicted=1.0
# windspeed      13.353159
# pressure      994.864682
# waveheight      6.219998
# Name: 6748, dtype: float64, Predicted=1.0
# windspeed       8.676323
# pressure      996.795403
# waveheight      1.856782
# Name: 10917, dtype: float64, Predicted=1.0
# windspeed       8.606555
# pressure      997.313109
# waveheight      8.111815
# Name: 9642, dtype: float64, Predicted=1.0
# windspeed      15.000194
# pressure      999.263751
# waveheight      3.083605
# Name: 6865, dtype: float64, Predicted=1.0
# windspeed      12.134391
# pressure      998.894574
# waveheight      9.000000
# Name: 10673, dtype: float64, Predicted=1.0
# windspeed      11.120219
# pressure      997.239829
# waveheight      2.026090
# Name: 11192, dtype: float64, Predicted=1.0
# windspeed       9.312608
# pressure      994.896150
# waveheight      1.550318
# Name: 7060, dtype: float64, Predicted=1.0
# windspeed      11.349838
# pressure      998.841730
# waveheight      9.000000
# Name: 10282, dtype: float64, Predicted=1.0
# windspeed      14.261280
# pressure      999.422560
# waveheight      2.954085
# Name: 7254, dtype: float64, Predicted=1.0
# windspeed       8.053972
# pressure      999.333588
# waveheight      2.433703
# Name: 10979, dtype: float64, Predicted=1.0
# windspeed       12.00
# pressure      1021.30
# waveheight       1.52
# Name: 4974, dtype: float64, Predicted=1.0
# windspeed      14.090279
# pressure      998.821872
# waveheight      3.916347
# Name: 7703, dtype: float64, Predicted=1.0
# windspeed       8.150550
# pressure      998.434460
# waveheight      1.407002
# Name: 8006, dtype: float64, Predicted=1.0
# windspeed       8.642340
# pressure      996.416991
# waveheight      7.472410
# Name: 9334, dtype: float64, Predicted=1.0
# windspeed      16.082182
# pressure      960.568218
# waveheight      6.284793
# Name: 8714, dtype: float64, Predicted=1.0
# windspeed      13.982433
# pressure      998.821318
# waveheight      3.846862
# Name: 8326, dtype: float64, Predicted=1.0
# windspeed       9.377868
# pressure      983.390737
# waveheight      4.965662
# Name: 9310, dtype: float64, Predicted=1.0
# windspeed      15.645642
# pressure      992.767103
# waveheight      4.021340
# Name: 10078, dtype: float64, Predicted=1.0
# windspeed       9.775212
# pressure      998.776912
# waveheight      2.269228
# Name: 10622, dtype: float64, Predicted=1.0
# windspeed      14.100000
# pressure      995.649954
# waveheight      2.971127
# Name: 6575, dtype: float64, Predicted=1.0
# windspeed      12.709238
# pressure      998.952867
# waveheight      2.598886
# Name: 8016, dtype: float64, Predicted=1.0
# windspeed       7.867328
# pressure      996.873440
# waveheight      9.000000
# Name: 9205, dtype: float64, Predicted=1.0
# windspeed      16.654205
# pressure      968.399092
# waveheight      6.151824
# Name: 6260, dtype: float64, Predicted=1.0
# windspeed      12.139776
# pressure      992.413978
# waveheight      4.371997
# Name: 6136, dtype: float64, Predicted=1.0
# windspeed       7.942828
# pressure      996.271212
# waveheight      1.832656
# Name: 11836, dtype: float64, Predicted=1.0
# windspeed       8.795296
# pressure      999.350882
# waveheight      4.070357
# Name: 6358, dtype: float64, Predicted=1.0
# windspeed        7.9
# pressure      1010.2
# waveheight       9.0
# Name: 3658, dtype: float64, Predicted=1.0
# windspeed      11.576222
# pressure      997.998811
# waveheight      1.178573
# Name: 8523, dtype: float64, Predicted=1.0
# windspeed      16.548522
# pressure      978.601974
# waveheight      7.640986
# Name: 6199, dtype: float64, Predicted=1.0
# windspeed       10.50
# pressure      1008.90
# waveheight       1.71
# Name: 2818, dtype: float64, Predicted=1.0
# windspeed       4.736321
# pressure      995.296856
# waveheight      7.978170
# Name: 8875, dtype: float64, Predicted=1.0
# windspeed      12.024475
# pressure      996.615596
# waveheight      3.022453
# Name: 7890, dtype: float64, Predicted=1.0
# windspeed      13.107019
# pressure      995.726319
# waveheight      2.840790
# Name: 7864, dtype: float64, Predicted=1.0
# windspeed       9.415762
# pressure      997.837627
# waveheight      3.608647
# Name: 7094, dtype: float64, Predicted=1.0
# windspeed       12.20
# pressure      1012.50
# waveheight       1.96
# Name: 4136, dtype: float64, Predicted=1.0
# windspeed      14.548324
# pressure      999.806894
# waveheight      3.627805
# Name: 8874, dtype: float64, Predicted=1.0
# windspeed      13.338440
# pressure      993.446147
# waveheight      6.657998
# Name: 10152, dtype: float64, Predicted=1.0
# windspeed       10.4
# pressure      1010.4
# waveheight       2.3
# Name: 2402, dtype: float64, Predicted=1.0
# windspeed      12.111893
# pressure      996.625405
# waveheight      2.754336
# Name: 7570, dtype: float64, Predicted=1.0
# windspeed       9.667791
# pressure      998.796225
# waveheight      2.596819
# Name: 10656, dtype: float64, Predicted=1.0
# windspeed      16.509973
# pressure      994.590088
# waveheight      9.000000
# Name: 7327, dtype: float64, Predicted=1.0
# windspeed      16.494593
# pressure      988.714854
# waveheight      3.312300
# Name: 8418, dtype: float64, Predicted=1.0
# windspeed       9.252113
# pressure      995.048732
# waveheight      2.639746
# Name: 10117, dtype: float64, Predicted=1.0
# windspeed       7.932365
# pressure      997.463012
# waveheight      2.171506
# Name: 9035, dtype: float64, Predicted=1.0
# windspeed      11.536623
# pressure      997.087906
# waveheight      2.219726
# Name: 7829, dtype: float64, Predicted=1.0
# windspeed      13.974979
# pressure      999.832955
# waveheight      5.131532
# Name: 10671, dtype: float64, Predicted=1.0
# windspeed       9.891580
# pressure      997.875894
# waveheight      1.704221
# Name: 10574, dtype: float64, Predicted=1.0
# windspeed       7.814605
# pressure      997.521349
# waveheight      2.179326
# Name: 8906, dtype: float64, Predicted=1.0
# windspeed      18.917038
# pressure      991.238200
# waveheight      9.000000
# Name: 10814, dtype: float64, Predicted=1.0
# windspeed       8.844001
# pressure      997.788003
# waveheight      7.090794
# Name: 6574, dtype: float64, Predicted=1.0
# windspeed      13.802527
# pressure      998.610010
# waveheight      2.361860
# Name: 10595, dtype: float64, Predicted=1.0
# windspeed      15.312669
# pressure      999.435957
# waveheight      2.999623
# Name: 10983, dtype: float64, Predicted=1.0
# windspeed       8.895706
# pressure      996.900000
# waveheight      5.949155
# Name: 6353, dtype: float64, Predicted=1.0
# windspeed       9.915869
# pressure      998.216237
# waveheight      2.118266
# Name: 8165, dtype: float64, Predicted=1.0
# windspeed      11.215347
# pressure      997.236790
# waveheight      2.119426
# Name: 9945, dtype: float64, Predicted=1.0
# windspeed       9.213990
# pressure      983.650532
# waveheight      4.933579
# Name: 9307, dtype: float64, Predicted=1.0
# windspeed       8.064606
# pressure      999.017345
# waveheight      1.834958
# Name: 9058, dtype: float64, Predicted=1.0
# windspeed        8.1
# pressure      1018.2
# waveheight       9.0
# Name: 3763, dtype: float64, Predicted=1.0
# windspeed      11.760977
# pressure      998.229966
# waveheight      1.237492
# Name: 10017, dtype: float64, Predicted=1.0
# windspeed      10.550811
# pressure      992.528940
# waveheight      4.232765
# Name: 6984, dtype: float64, Predicted=1.0
# windspeed      10.734849
# pressure      998.987216
# waveheight      8.046441
# Name: 10183, dtype: float64, Predicted=1.0
# windspeed       8.197458
# pressure      997.473870
# waveheight      9.000000
# Name: 7568, dtype: float64, Predicted=1.0
# windspeed      14.10
# pressure      995.90
# waveheight      3.02
# Name: 39, dtype: float64, Predicted=1.0
# windspeed      14.80
# pressure      982.50
# waveheight      3.69
# Name: 4938, dtype: float64, Predicted=1.0
# windspeed       11.00
# pressure      1006.30
# waveheight       2.79
# Name: 1892, dtype: float64, Predicted=1.0
# windspeed      15.134299
# pressure      995.096739
# waveheight      3.813285
# Name: 7051, dtype: float64, Predicted=1.0
# windspeed      11.340282
# pressure      998.500235
# waveheight      2.433958
# Name: 7412, dtype: float64, Predicted=1.0
# windspeed       7.996472
# pressure      996.698236
# waveheight      1.804708
# Name: 8566, dtype: float64, Predicted=1.0
# windspeed       8.123326
# pressure      998.427727
# waveheight      2.954169
# Name: 9979, dtype: float64, Predicted=1.0
# windspeed       8.211855
# pressure      997.577964
# waveheight      2.217287
# Name: 7383, dtype: float64, Predicted=1.0
# windspeed      14.652683
# pressure      998.914396
# waveheight      2.476463
# Name: 8233, dtype: float64, Predicted=1.0
# windspeed      10.430111
# pressure      996.885579
# waveheight      2.943740
# Name: 11800, dtype: float64, Predicted=1.0
# windspeed      11.136814
# pressure      999.192035
# waveheight      2.392991
# Name: 8810, dtype: float64, Predicted=1.0
# windspeed      16.341000
# pressure      988.866995
# waveheight      9.000000
# Name: 8388, dtype: float64, Predicted=1.0
# windspeed      15.550697
# pressure      960.378702
# waveheight      6.036687
# Name: 9618, dtype: float64, Predicted=1.0
# windspeed      15.297809
# pressure      996.104929
# waveheight      4.121628
# Name: 7265, dtype: float64, Predicted=1.0
# windspeed      14.673289
# pressure      996.507613
# waveheight      3.814962
# Name: 6605, dtype: float64, Predicted=1.0
# windspeed       8.828082
# pressure      994.647111
# waveheight      1.382555
# Name: 7619, dtype: float64, Predicted=1.0
# windspeed      13.344608
# pressure      996.617279
# waveheight      2.867518
# Name: 11726, dtype: float64, Predicted=1.0
# windspeed       8.007320
# pressure      998.012594
# waveheight      9.000000
# Name: 7993, dtype: float64, Predicted=1.0
# windspeed      14.214538
# pressure      998.630661
# waveheight      2.743392
# Name: 10430, dtype: float64, Predicted=1.0
# windspeed      10.489087
# pressure      998.492724
# waveheight      1.435926
# Name: 8536, dtype: float64, Predicted=1.0
# windspeed       8.426136
# pressure      997.353031
# waveheight      2.140000
# Name: 8575, dtype: float64, Predicted=1.0
# windspeed      11.685017
# pressure      998.641260
# waveheight      1.962985
# Name: 7589, dtype: float64, Predicted=1.0
# windspeed      12.586382
# pressure      998.360852
# waveheight      9.000000
# Name: 7520, dtype: float64, Predicted=1.0
# windspeed       9.123093
# pressure      995.761546
# waveheight      2.253856
# Name: 11615, dtype: float64, Predicted=1.0
# windspeed       9.176411
# pressure      997.838206
# waveheight      1.472193
# Name: 10492, dtype: float64, Predicted=1.0
# windspeed        8.90
# pressure      1001.90
# waveheight       1.17
# Name: 4400, dtype: float64, Predicted=1.0
# windspeed       8.931939
# pressure      997.560252
# waveheight      1.587768
# Name: 10008, dtype: float64, Predicted=1.0
# windspeed       9.380995
# pressure      995.423622
# waveheight      2.469574
# Name: 11373, dtype: float64, Predicted=1.0
# windspeed      12.499897
# pressure      999.899353
# waveheight      9.000000
# Name: 6523, dtype: float64, Predicted=1.0
# windspeed      16.104424
# pressure      995.896856
# waveheight      9.000000
# Name: 8571, dtype: float64, Predicted=1.0
# windspeed      10.358747
# pressure      997.824752
# waveheight      1.727525
# Name: 11655, dtype: float64, Predicted=1.0
# windspeed       7.836009
# pressure      997.168004
# waveheight      1.170602
# Name: 10818, dtype: float64, Predicted=1.0
# windspeed      14.765070
# pressure      997.402973
# waveheight      9.000000
# Name: 10446, dtype: float64, Predicted=1.0
# windspeed       7.90
# pressure      999.00
# waveheight      3.01
# Name: 541, dtype: float64, Predicted=1.0
# windspeed      11.511500
# pressure      996.820749
# waveheight      8.619354
# Name: 6533, dtype: float64, Predicted=1.0
# windspeed       9.078409
# pressure      999.458884
# waveheight      1.541395
# Name: 11267, dtype: float64, Predicted=1.0
# windspeed      11.585873
# pressure      993.581599
# waveheight      9.000000
# Name: 7530, dtype: float64, Predicted=1.0
# windspeed      10.612822
# pressure      997.634472
# waveheight      1.817493
# Name: 11070, dtype: float64, Predicted=1.0
# windspeed       7.3
# pressure      999.6
# waveheight      3.2
# Name: 2177, dtype: float64, Predicted=1.0
# windspeed       8.636822
# pressure      996.746027
# waveheight      1.822219
# Name: 10355, dtype: float64, Predicted=1.0
# windspeed      14.649938
# pressure      999.474598
# waveheight      3.212478
# Name: 9543, dtype: float64, Predicted=1.0
# windspeed      15.675697
# pressure      997.688278
# waveheight      3.094832
# Name: 11884, dtype: float64, Predicted=1.0
# windspeed      14.820401
# pressure      981.337149
# waveheight      3.766503
# Name: 9250, dtype: float64, Predicted=1.0
# windspeed      12.730130
# pressure      999.280981
# waveheight      3.054374
# Name: 10779, dtype: float64, Predicted=1.0
# windspeed      12.477989
# pressure      996.201328
# waveheight      9.000000
# Name: 11820, dtype: float64, Predicted=1.0
# windspeed      11.650648
# pressure      999.268140
# waveheight      1.734003
# Name: 9550, dtype: float64, Predicted=1.0
# windspeed       8.236808
# pressure      999.247362
# waveheight      1.245765
# Name: 9798, dtype: float64, Predicted=1.0
# windspeed      15.241290
# pressure      991.662493
# waveheight      3.837997
# Name: 11082, dtype: float64, Predicted=1.0
# windspeed       7.490405
# pressure      988.257562
# waveheight      4.958448
# Name: 7616, dtype: float64, Predicted=1.0
# windspeed      14.632140
# pressure      996.744631
# waveheight      7.938287
# Name: 7225, dtype: float64, Predicted=1.0
# windspeed      10.239240
# pressure      998.273520
# waveheight      1.767636
# Name: 11108, dtype: float64, Predicted=1.0
# windspeed       4.894871
# pressure      995.552565
# waveheight      8.000298
# Name: 11587, dtype: float64, Predicted=1.0
# windspeed        8.80
# pressure      1004.50
# waveheight       2.48
# Name: 2017, dtype: float64, Predicted=1.0
# windspeed       8.892945
# pressure      998.551289
# waveheight      1.443012
# Name: 7059, dtype: float64, Predicted=1.0
# windspeed      12.513913
# pressure      992.451391
# waveheight      6.384853
# Name: 11521, dtype: float64, Predicted=1.0
# windspeed      15.125241
# pressure      992.208941
# waveheight      2.586605
# Name: 9897, dtype: float64, Predicted=1.0
# windspeed      11.502468
# pressure      998.364679
# waveheight      2.063429
# Name: 11180, dtype: float64, Predicted=1.0
# windspeed       8.611211
# pressure      998.416817
# waveheight      1.333246
# Name: 8440, dtype: float64, Predicted=1.0
# windspeed       7.235765
# pressure      999.587153
# waveheight      3.165313
# Name: 11285, dtype: float64, Predicted=1.0
# windspeed       9.171221
# pressure      995.785610
# waveheight      2.282733
# Name: 7660, dtype: float64, Predicted=1.0
# windspeed       9.089024
# pressure      995.842684
# waveheight      8.696005
# Name: 8198, dtype: float64, Predicted=1.0
# windspeed      10.174975
# pressure      997.260595
# waveheight      2.273020
# Name: 11296, dtype: float64, Predicted=1.0
# windspeed      14.598878
# pressure      999.026610
# waveheight      3.147451
# Name: 7807, dtype: float64, Predicted=1.0
# windspeed      13.900495
# pressure      996.184228
# waveheight      3.905070
# Name: 7005, dtype: float64, Predicted=1.0
# windspeed      14.164725
# pressure      994.641263
# waveheight      4.981887
# Name: 7855, dtype: float64, Predicted=1.0
# windspeed       7.457833
# pressure      996.663251
# waveheight      1.715366
# Name: 11329, dtype: float64, Predicted=1.0
# windspeed      15.889651
# pressure      996.267270
# waveheight      3.446643
# Name: 11252, dtype: float64, Predicted=1.0
# windspeed      11.131896
# pressure      998.383800
# waveheight      2.938455
# Name: 8480, dtype: float64, Predicted=1.0
# windspeed      11.780236
# pressure      997.505679
# waveheight      6.348266
# Name: 10343, dtype: float64, Predicted=1.0
# windspeed      13.005852
# pressure      992.812214
# waveheight      4.161947
# Name: 7574, dtype: float64, Predicted=1.0
# windspeed      12.330277
# pressure      998.595125
# waveheight      2.453825
# Name: 10994, dtype: float64, Predicted=1.0
# windspeed        9.80
# pressure      1013.10
# waveheight       1.39
# Name: 5166, dtype: float64, Predicted=1.0
# windspeed      15.251393
# pressure      975.309080
# waveheight      4.397534
# Name: 10257, dtype: float64, Predicted=1.0
# windspeed       11.30
# pressure      1011.60
# waveheight       1.79
# Name: 3183, dtype: float64, Predicted=1.0
# windspeed       7.962223
# pressure      996.416675
# waveheight      1.967452
# Name: 7169, dtype: float64, Predicted=1.0
# windspeed       9.845846
# pressure      998.826692
# waveheight      2.199408
# Name: 10437, dtype: float64, Predicted=1.0
# windspeed      11.350912
# pressure      997.060402
# waveheight      2.120931
# Name: 11467, dtype: float64, Predicted=1.0
# windspeed      15.678055
# pressure      997.646299
# waveheight      3.613184
# Name: 10190, dtype: float64, Predicted=1.0
# windspeed       9.480336
# pressure      996.682371
# waveheight      0.859186
# Name: 9102, dtype: float64, Predicted=1.0
# windspeed      17.041641
# pressure      974.993322
# waveheight      4.537119
# Name: 9785, dtype: float64, Predicted=1.0
# windspeed       7.466201
# pressure      996.311248
# waveheight      1.906561
# Name: 8525, dtype: float64, Predicted=1.0
# windspeed      10.115932
# pressure      998.243955
# waveheight      1.342223
# Name: 9021, dtype: float64, Predicted=1.0
# windspeed       12.90
# pressure      1008.70
# waveheight       2.13
# Name: 1607, dtype: float64, Predicted=1.0
# windspeed      10.660623
# pressure      994.827461
# waveheight      2.791347
# Name: 7223, dtype: float64, Predicted=1.0
# windspeed      14.226037
# pressure      993.641672
# waveheight      2.744745
# Name: 10020, dtype: float64, Predicted=1.0
# windspeed       8.436333
# pressure      999.681833
# waveheight      1.086628
# Name: 10759, dtype: float64, Predicted=1.0
# windspeed      15.847713
# pressure      996.539866
# waveheight      3.493823
# Name: 9479, dtype: float64, Predicted=1.0
# windspeed       7.443582
# pressure      999.058326
# waveheight      2.926214
# Name: 10657, dtype: float64, Predicted=1.0
# windspeed       10.30
# pressure      1000.70
# waveheight       2.06
# Name: 275, dtype: float64, Predicted=1.0
# windspeed       7.748560
# pressure      996.602881
# waveheight      1.963642
# Name: 9909, dtype: float64, Predicted=1.0
# windspeed       8.390342
# pressure      998.954829
# waveheight      1.681689
# Name: 9361, dtype: float64, Predicted=1.0
# windspeed        6.5
# pressure      1015.6
# waveheight       9.0
# Name: 5653, dtype: float64, Predicted=1.0
# windspeed       9.212567
# pressure      995.153398
# waveheight      1.751828
# Name: 7289, dtype: float64, Predicted=1.0
# windspeed        6.500000
# pressure      1016.085292
# waveheight       9.000000
# Name: 5925, dtype: float64, Predicted=1.0
# windspeed       8.431076
# pressure      998.146614
# waveheight      1.240926
# Name: 11690, dtype: float64, Predicted=1.0
# windspeed      11.744195
# pressure      995.695981
# waveheight      2.435223
# Name: 8816, dtype: float64, Predicted=1.0
# windspeed       7.991445
# pressure      996.635836
# waveheight      2.170542
# Name: 8003, dtype: float64, Predicted=1.0
# windspeed      10.891466
# pressure      995.132429
# waveheight      2.694608
# Name: 8468, dtype: float64, Predicted=1.0
# windspeed      12.863807
# pressure      999.883463
# waveheight      8.045833
# Name: 10469, dtype: float64, Predicted=1.0
# windspeed      11.848205
# pressure      994.221794
# waveheight      7.540027
# Name: 7686, dtype: float64, Predicted=1.0
# windspeed      13.328337
# pressure      987.671844
# waveheight      3.290549
# Name: 8631, dtype: float64, Predicted=1.0
# windspeed      15.240189
# pressure      995.629157
# waveheight      3.926375
# Name: 7626, dtype: float64, Predicted=1.0
# windspeed       9.882644
# pressure      995.019835
# waveheight      2.450041
# Name: 11812, dtype: float64, Predicted=1.0
# windspeed       8.426150
# pressure      999.447701
# waveheight      1.486078
# Name: 9016, dtype: float64, Predicted=1.0
# windspeed       8.103351
# pressure      998.708937
# waveheight      1.272458
# Name: 8316, dtype: float64, Predicted=1.0
# windspeed       8.054462
# pressure      997.581693
# waveheight      1.047912
# Name: 8381, dtype: float64, Predicted=1.0
# windspeed      10.402306
# pressure      997.832279
# waveheight      1.756284
# Name: 10841, dtype: float64, Predicted=1.0
# windspeed      14.119324
# pressure      998.757972
# waveheight      2.934652
# Name: 10029, dtype: float64, Predicted=1.0
# windspeed       12.50
# pressure      1023.70
# waveheight       1.86
# Name: 4389, dtype: float64, Predicted=1.0
# windspeed       13.00
# pressure      1008.60
# waveheight       2.61
# Name: 4290, dtype: float64, Predicted=1.0
# windspeed      16.397181
# pressure      999.570891
# waveheight      2.690047
# Name: 8112, dtype: float64, Predicted=1.0
# windspeed      14.832141
# pressure      996.116523
# waveheight      3.828393
# Name: 9496, dtype: float64, Predicted=1.0
# windspeed      11.614771
# pressure      998.021102
# waveheight      1.185276
# Name: 9461, dtype: float64, Predicted=1.0
# windspeed        9.60
# pressure      1012.00
# waveheight       1.61
# Name: 5712, dtype: float64, Predicted=1.0
# windspeed       8.100610
# pressure      997.404268
# waveheight      1.729512
# Name: 10109, dtype: float64, Predicted=1.0
# windspeed       10.50
# pressure      1008.00
# waveheight       1.66
# Name: 2280, dtype: float64, Predicted=1.0
# windspeed        9.10
# pressure      1013.60
# waveheight       1.52
# Name: 1568, dtype: float64, Predicted=1.0
# windspeed       10.60
# pressure      1024.30
# waveheight       1.57
# Name: 4170, dtype: float64, Predicted=1.0
# windspeed       7.476536
# pressure      996.383296
# waveheight      2.109176
# Name: 9706, dtype: float64, Predicted=1.0
# windspeed      10.077174
# pressure      997.545248
# waveheight      2.220098
# Name: 9963, dtype: float64, Predicted=1.0
# windspeed      13.193352
# pressure      998.790636
# waveheight      9.000000
# Name: 8762, dtype: float64, Predicted=1.0
# windspeed       9.790044
# pressure      997.042423
# waveheight      2.107273
# Name: 6459, dtype: float64, Predicted=1.0
# windspeed      12.316397
# pressure      998.431458
# waveheight      1.958494
# Name: 10967, dtype: float64, Predicted=1.0
# windspeed       9.923776
# pressure      998.732736
# waveheight      4.493613
# Name: 10322, dtype: float64, Predicted=1.0
# windspeed       9.553176
# pressure      994.457932
# waveheight      1.219282
# Name: 8796, dtype: float64, Predicted=1.0
# windspeed      11.149246
# pressure      999.223114
# waveheight      2.350102
# Name: 7754, dtype: float64, Predicted=1.0
# windspeed      10.18614
# pressure      999.30000
# waveheight      2.28499
# Name: 8109, dtype: float64, Predicted=1.0
# windspeed       11.10
# pressure      1020.40
# waveheight       1.68
# Name: 4890, dtype: float64, Predicted=1.0
# windspeed      11.849386
# pressure      998.737142
# waveheight      1.820532
# Name: 9914, dtype: float64, Predicted=1.0
# windspeed       9.767619
# pressure      997.558278
# waveheight      2.124962
# Name: 11117, dtype: float64, Predicted=1.0
# windspeed       8.190172
# pressure      998.048042
# waveheight      2.871304
# Name: 8897, dtype: float64, Predicted=1.0
# windspeed      10.900568
# pressure      997.928717
# waveheight      1.901623
# Name: 10489, dtype: float64, Predicted=1.0
# windspeed       9.1
# pressure      996.9
# waveheight      1.8
# Name: 2529, dtype: float64, Predicted=1.0
# windspeed      11.254694
# pressure      998.270995
# waveheight      2.470000
# Name: 8078, dtype: float64, Predicted=1.0
# windspeed        9.4
# pressure      1026.6
# waveheight       9.0
# Name: 6067, dtype: float64, Predicted=1.0
# windspeed      12.922075
# pressure      999.880815
# waveheight      7.893013
# Name: 10021, dtype: float64, Predicted=1.0
# windspeed      12.298329
# pressure      996.984704
# waveheight      3.103419
# Name: 8594, dtype: float64, Predicted=1.0
# windspeed       8.555603
# pressure      999.188794
# waveheight      1.466660
# Name: 9627, dtype: float64, Predicted=1.0
# windspeed      11.667943
# pressure      998.543547
# waveheight      1.995320
# Name: 6701, dtype: float64, Predicted=1.0
# windspeed      10.299634
# pressure      998.000183
# waveheight      2.440381
# Name: 10115, dtype: float64, Predicted=1.0
# windspeed       9.554710
# pressure      997.310323
# waveheight      2.273768
# Name: 9675, dtype: float64, Predicted=1.0
# windspeed       8.427291
# pressure      996.900000
# waveheight      8.832036
# Name: 9902, dtype: float64, Predicted=1.0
# windspeed      16.433462
# pressure      987.664988
# waveheight      9.000000
# Name: 7346, dtype: float64, Predicted=1.0
# windspeed      15.660611
# pressure      997.787415
# waveheight      3.090737
# Name: 8667, dtype: float64, Predicted=1.0
# windspeed       8.601609
# pressure      997.086101
# waveheight      7.929919
# Name: 11889, dtype: float64, Predicted=1.0
# windspeed      12.711852
# pressure      993.696588
# waveheight      4.987773
# Name: 9132, dtype: float64, Predicted=1.0
# windspeed      11.175865
# pressure      994.929652
# waveheight      2.745241
# Name: 8395, dtype: float64, Predicted=1.0
# windspeed      14.700779
# pressure      997.126034
# waveheight      2.866555
# Name: 10328, dtype: float64, Predicted=1.0
# windspeed      14.177908
# pressure      997.926186
# waveheight      3.483437
# Name: 11881, dtype: float64, Predicted=1.0
# windspeed        8.70
# pressure      1012.00
# waveheight       2.27
# Name: 4792, dtype: float64, Predicted=1.0
# windspeed      11.2
# pressure      998.9
# waveheight      9.0
# Name: 654, dtype: float64, Predicted=1.0
# windspeed       9.262366
# pressure      999.300000
# waveheight      2.617548
# Name: 6875, dtype: float64, Predicted=1.0
# windspeed       12.80
# pressure      1017.10
# waveheight       1.65
# Name: 4011, dtype: float64, Predicted=1.0
# windspeed       12.40
# pressure      1027.00
# waveheight       1.55
# Name: 597, dtype: float64, Predicted=1.0
# windspeed       8.414408
# pressure      999.471184
# waveheight      1.487839
# Name: 7395, dtype: float64, Predicted=1.0
# windspeed       8.670374
# pressure      998.930629
# waveheight      1.588478
# Name: 10847, dtype: float64, Predicted=1.0
# windspeed      15.909966
# pressure      994.470448
# waveheight      9.000000
# Name: 7266, dtype: float64, Predicted=1.0
# windspeed        9.70
# pressure      1018.80
# waveheight       1.37
# Name: 3884, dtype: float64, Predicted=1.0
# windspeed       8.459655
# pressure      997.565884
# waveheight      2.870086
# Name: 8377, dtype: float64, Predicted=1.0
# windspeed      16.450690
# pressure      965.092543
# waveheight      6.060751
# Name: 8108, dtype: float64, Predicted=1.0
# windspeed       11.90
# pressure      1019.20
# waveheight       1.93
# Name: 2985, dtype: float64, Predicted=1.0
# windspeed        9.60
# pressure      1013.80
# waveheight       1.75
# Name: 1172, dtype: float64, Predicted=1.0
# windspeed       7.614837
# pressure      997.571291
# waveheight      2.154355
# Name: 6937, dtype: float64, Predicted=1.0
# windspeed       8.108406
# pressure      999.221681
# waveheight      1.159136
# Name: 11562, dtype: float64, Predicted=1.0
# windspeed      10.605981
# pressure      995.057997
# waveheight      2.673199
# Name: 11559, dtype: float64, Predicted=1.0
# windspeed       10.80
# pressure      1013.00
# waveheight       1.55
# Name: 1194, dtype: float64, Predicted=1.0
# windspeed      15.421052
# pressure      999.361659
# waveheight      3.025714
# Name: 7331, dtype: float64, Predicted=1.0
# windspeed       9.383019
# pressure      995.302956
# waveheight      2.379261
# Name: 10544, dtype: float64, Predicted=1.0
# windspeed        8.90
# pressure      1008.20
# waveheight       0.96
# Name: 2193, dtype: float64, Predicted=1.0
# windspeed       12.10
# pressure      1007.50
# waveheight       2.32
# Name: 159, dtype: float64, Predicted=1.0
# windspeed      13.391923
# pressure      993.463974
# waveheight      6.372313
# Name: 9314, dtype: float64, Predicted=1.0
# windspeed      11.873375
# pressure      996.835917
# waveheight      9.000000
# Name: 7628, dtype: float64, Predicted=1.0
# windspeed       15.3
# pressure      1004.1
# waveheight       9.0
# Name: 3885, dtype: float64, Predicted=1.0
# windspeed       12.00
# pressure      1009.50
# waveheight       2.01
# Name: 5747, dtype: float64, Predicted=1.0
# windspeed       8.603150
# pressure      998.873706
# waveheight      1.271821
# Name: 11882, dtype: float64, Predicted=1.0
# windspeed      14.404840
# pressure      997.881462
# waveheight      3.126694
# Name: 7523, dtype: float64, Predicted=1.0
# windspeed      11.269117
# pressure      999.522791
# waveheight      1.936548
# Name: 10258, dtype: float64, Predicted=1.0
# windspeed       9.096028
# pressure      997.798014
# waveheight      1.454106
# Name: 9617, dtype: float64, Predicted=1.0
# windspeed       8.778406
# pressure      997.858072
# waveheight      2.916303
# Name: 9539, dtype: float64, Predicted=1.0
# windspeed       8.008182
# pressure      997.512274
# waveheight      1.024193
# Name: 11525, dtype: float64, Predicted=1.0
# windspeed      10.291119
# pressure      998.256277
# waveheight      2.268873
# Name: 7305, dtype: float64, Predicted=1.0
# windspeed       8.255827
# pressure      997.398446
# waveheight      2.140000
# Name: 7947, dtype: float64, Predicted=1.0
# windspeed        9.40
# pressure      1005.50
# waveheight       1.79
# Name: 1563, dtype: float64, Predicted=1.0
# windspeed       9.289288
# pressure      996.741966
# waveheight      0.875755
# Name: 6953, dtype: float64, Predicted=1.0
# windspeed       9.676897
# pressure      997.693678
# waveheight      3.794098
# Name: 10947, dtype: float64, Predicted=1.0
# windspeed       10.50
# pressure      1020.60
# waveheight       2.21
# Name: 2154, dtype: float64, Predicted=1.0
# windspeed       9.669002
# pressure      996.700297
# waveheight      2.821306
# Name: 10361, dtype: float64, Predicted=1.0
# windspeed       9.182012
# pressure      998.638262
# waveheight      1.756357
# Name: 6425, dtype: float64, Predicted=1.0
# windspeed      10.805415
# pressure      998.994585
# waveheight      2.270144
# Name: 10472, dtype: float64, Predicted=1.0
# windspeed      11.687325
# pressure      998.436193
# waveheight      2.415537
# Name: 9761, dtype: float64, Predicted=1.0
# windspeed       11.4
# pressure      1029.4
# waveheight       1.5
# Name: 1550, dtype: float64, Predicted=1.0
# windspeed      17.169105
# pressure      975.408823
# waveheight      5.775029
# Name: 7465, dtype: float64, Predicted=1.0
# windspeed       6.028815
# pressure      988.700000
# waveheight      4.310000
# Name: 5601, dtype: float64, Predicted=1.0
# windspeed       8.203049
# pressure      995.545427
# waveheight      1.933199
# Name: 10209, dtype: float64, Predicted=1.0
# windspeed       5.351580
# pressure      995.127602
# waveheight      5.973773
# Name: 7618, dtype: float64, Predicted=1.0
# windspeed       8.363717
# pressure      994.428691
# waveheight      1.113367
# Name: 10120, dtype: float64, Predicted=1.0
# windspeed       9.810049
# pressure      999.090442
# waveheight      2.347611
# Name: 10366, dtype: float64, Predicted=1.0
# windspeed       6.697044
# pressure      994.779570
# waveheight      4.701100
# Name: 9121, dtype: float64, Predicted=1.0
# windspeed       11.20
# pressure      1009.00
# waveheight       1.59
# Name: 2421, dtype: float64, Predicted=1.0
# windspeed       8.208749
# pressure      998.367455
# waveheight      1.239102
# Name: 8541, dtype: float64, Predicted=1.0
# windspeed      12.407957
# pressure      998.423346
# waveheight      1.968461
# Name: 9860, dtype: float64, Predicted=1.0
# windspeed       9.276514
# pressure      996.822946
# waveheight      1.257543
# Name: 10880, dtype: float64, Predicted=1.0
# windspeed      14.968033
# pressure      981.389000
# waveheight      5.339829
# Name: 6126, dtype: float64, Predicted=1.0
# windspeed       9.988522
# pressure      996.812595
# waveheight      1.035815
# Name: 11497, dtype: float64, Predicted=1.0
# windspeed       9.530309
# pressure      999.680440
# waveheight      1.665097
# ...
# pressure      999.658803
# waveheight      3.268716
# Name: 10269, dtype: float64, Predicted=1.0
# windspeed       10.00
# pressure      1021.20
# waveheight       1.05
# Name: 5018, dtype: float64, Predicted=1.0
# windspeed        5.700000
# pressure      1016.085292
# waveheight       9.000000
# Name: 3320, dtype: float64, Predicted=1.0
# windspeed      14.380795
# pressure      999.661590
# waveheight      2.962053
# Name: 7049, dtype: float64, Predicted=1.0
# windspeed      14.437708
# pressure      999.775415
# waveheight      2.965847
# Name: 7793, dtype: float64, Predicted=1.0
# windspeed       8.767776
# pressure      997.408717
# waveheight      1.626915
# Name: 6123, dtype: float64, Predicted=1.0
# windspeed      11.115231
# pressure      995.000836
# waveheight      2.670511
# Name: 6351, dtype: float64, Predicted=1.0
# windspeed      16.018616
# pressure      958.539351
# waveheight      6.265213
# Name: 7085, dtype: float64, Predicted=1.0
# windspeed       8.741086
# pressure      996.844716
# waveheight      2.799728
# Name: 6427, dtype: float64, Predicted=1.0
# windspeed       8.601441
# pressure      997.302881
# waveheight      8.133805
# Name: 10926, dtype: float64, Predicted=1.0
# windspeed      16.599691
# pressure      985.458572
# waveheight      8.991838
# Name: 6473, dtype: float64, Predicted=1.0
# windspeed       8.305564
# pressure      997.385183
# waveheight      2.140000
# Name: 9472, dtype: float64, Predicted=1.0
# windspeed      12.106085
# pressure      998.722978
# waveheight      1.360745
# Name: 7286, dtype: float64, Predicted=1.0
# windspeed      15.525093
# pressure      995.470311
# waveheight      4.134348
# Name: 6155, dtype: float64, Predicted=1.0
# windspeed      12.820861
# pressure      995.917108
# waveheight      2.725243
# Name: 8436, dtype: float64, Predicted=1.0
# windspeed      17.068381
# pressure      973.255227
# waveheight      4.718282
# Name: 7783, dtype: float64, Predicted=1.0
# windspeed       16.0
# pressure      1005.9
# waveheight       9.0
# Name: 509, dtype: float64, Predicted=1.0
# windspeed       9.814856
# pressure      998.218192
# waveheight      1.657184
# Name: 8410, dtype: float64, Predicted=1.0
# windspeed      15.103610
# pressure      999.282647
# waveheight      2.950842
# Name: 8917, dtype: float64, Predicted=1.0
# windspeed       5.397987
# pressure      995.406058
# waveheight      7.677965
# Name: 6747, dtype: float64, Predicted=1.0
# windspeed      16.335625
# pressure      962.615175
# waveheight      6.183697
# Name: 7343, dtype: float64, Predicted=1.0
# windspeed      14.686665
# pressure      999.078484
# waveheight      3.133485
# Name: 7886, dtype: float64, Predicted=1.0
# windspeed       4.835284
# pressure      995.184968
# waveheight      8.371679
# Name: 7010, dtype: float64, Predicted=1.0
# windspeed      16.592383
# pressure      972.849330
# waveheight      6.284040
# Name: 8285, dtype: float64, Predicted=1.0
# windspeed       8.447670
# pressure      998.972617
# waveheight      3.070244
# Name: 8386, dtype: float64, Predicted=1.0
# windspeed       8.485511
# pressure      999.357958
# waveheight      1.373491
# Name: 8662, dtype: float64, Predicted=1.0
# windspeed       8.524863
# pressure      998.179868
# waveheight      2.980710
# Name: 11171, dtype: float64, Predicted=1.0
# windspeed      10.831923
# pressure      998.862441
# waveheight      9.000000
# Name: 11069, dtype: float64, Predicted=1.0
# windspeed       10.60
# pressure      1016.50
# waveheight       2.02
# Name: 5782, dtype: float64, Predicted=1.0
# windspeed       9.05438
# pressure      996.90000
# waveheight      4.97259
# Name: 7529, dtype: float64, Predicted=1.0
# windspeed      11.220358
# pressure      998.878188
# waveheight      9.000000
# Name: 9149, dtype: float64, Predicted=1.0
# windspeed       8.642204
# pressure      998.962890
# waveheight      3.091642
# Name: 9274, dtype: float64, Predicted=1.0
# windspeed      14.922301
# pressure      975.528829
# waveheight      4.148630
# Name: 8578, dtype: float64, Predicted=1.0
# windspeed      13.757852
# pressure      999.487876
# waveheight      3.857714
# Name: 10063, dtype: float64, Predicted=1.0
# windspeed      10.584918
# pressure      998.945246
# waveheight      1.927410
# Name: 8746, dtype: float64, Predicted=1.0
# windspeed      11.004998
# pressure      997.630134
# waveheight      1.089946
# Name: 10551, dtype: float64, Predicted=1.0
# windspeed        7.9
# pressure      1026.9
# waveheight       9.0
# Name: 3099, dtype: float64, Predicted=1.0
# windspeed      11.974245
# pressure      998.891415
# waveheight      1.945778
# Name: 11610, dtype: float64, Predicted=1.0
# windspeed      13.143366
# pressure      997.777304
# waveheight      6.891464
# Name: 10315, dtype: float64, Predicted=1.0
# windspeed       8.582690
# pressure      997.126323
# waveheight      1.909928
# Name: 9186, dtype: float64, Predicted=1.0
# windspeed       11.2
# pressure      1010.1
# waveheight       0.9
# Name: 1124, dtype: float64, Predicted=1.0
# windspeed      13.734430
# pressure      996.184539
# waveheight      9.000000
# Name: 8701, dtype: float64, Predicted=1.0
# windspeed       9.787363
# pressure      995.158560
# waveheight      2.678288
# Name: 10490, dtype: float64, Predicted=1.0
# windspeed       8.532709
# pressure      996.900000
# waveheight      8.183234
# Name: 8179, dtype: float64, Predicted=1.0
# windspeed       8.034913
# pressure      999.067456
# waveheight      2.654730
# Name: 11164, dtype: float64, Predicted=1.0
# windspeed        9.20
# pressure      1014.90
# waveheight       1.42
# Name: 1374, dtype: float64, Predicted=1.0
# windspeed       10.10
# pressure      1012.40
# waveheight       1.44
# Name: 5720, dtype: float64, Predicted=1.0
# windspeed      12.354526
# pressure      999.001870
# waveheight      7.067867
# Name: 8657, dtype: float64, Predicted=1.0
# windspeed      12.411224
# pressure      999.655866
# waveheight      9.000000
# Name: 11437, dtype: float64, Predicted=1.0
# windspeed      14.270928
# pressure      997.011032
# waveheight      3.079825
# Name: 8855, dtype: float64, Predicted=1.0
# windspeed      13.710262
# pressure      999.844988
# waveheight      5.825813
# Name: 9751, dtype: float64, Predicted=1.0
# windspeed      10.056274
# pressure      999.743726
# waveheight      2.501697
# Name: 11632, dtype: float64, Predicted=1.0
# windspeed       8.891558
# pressure      996.816623
# waveheight      1.795831
# Name: 6122, dtype: float64, Predicted=1.0
# windspeed      13.736826
# pressure      993.578942
# waveheight      4.529954
# Name: 8269, dtype: float64, Predicted=1.0
# windspeed      13.320923
# pressure      998.257456
# waveheight      2.507861
# Name: 9777, dtype: float64, Predicted=1.0
# windspeed      12.428851
# pressure      993.150489
# waveheight      4.773609
# Name: 7290, dtype: float64, Predicted=1.0
# windspeed       10.10
# pressure      1014.60
# waveheight       1.45
# Name: 1285, dtype: float64, Predicted=1.0
# windspeed      11.525281
# pressure      993.759268
# waveheight      9.000000
# Name: 10912, dtype: float64, Predicted=1.0
# windspeed      14.611688
# pressure      996.881936
# waveheight      3.843719
# Name: 10936, dtype: float64, Predicted=1.0
# windspeed      10.980002
# pressure      998.789232
# waveheight      2.208308
# Name: 8382, dtype: float64, Predicted=1.0
# windspeed       8.283733
# pressure      997.409333
# waveheight      1.675227
# Name: 7906, dtype: float64, Predicted=1.0
# windspeed        9.60
# pressure      1012.90
# waveheight       1.54
# Name: 935, dtype: float64, Predicted=1.0
# windspeed       8.418411
# pressure      999.467269
# waveheight      1.490205
# Name: 11556, dtype: float64, Predicted=1.0
# windspeed      14.204053
# pressure      994.757869
# waveheight      2.700990
# Name: 10909, dtype: float64, Predicted=1.0
# windspeed       8.892188
# pressure      995.975608
# waveheight      2.929594
# Name: 10031, dtype: float64, Predicted=1.0
# windspeed       12.8
# pressure      1027.2
# waveheight       9.0
# Name: 338, dtype: float64, Predicted=1.0
# windspeed      14.837015
# pressure      973.805559
# waveheight      4.273755
# Name: 11514, dtype: float64, Predicted=1.0
# windspeed      12.665418
# pressure      997.272397
# waveheight      1.962173
# Name: 6197, dtype: float64, Predicted=1.0
# windspeed      13.128746
# pressure      994.375305
# waveheight      6.656326
# Name: 10813, dtype: float64, Predicted=1.0
# windspeed      12.903665
# pressure      993.301222
# waveheight      8.980425
# Name: 9202, dtype: float64, Predicted=1.0
# windspeed      12.584732
# pressure      998.501922
# waveheight      9.000000
# Name: 7796, dtype: float64, Predicted=1.0
# windspeed       7.457768
# pressure      997.045056
# waveheight      2.170847
# Name: 8094, dtype: float64, Predicted=1.0
# windspeed      13.810281
# pressure      998.363555
# waveheight      2.919907
# Name: 8298, dtype: float64, Predicted=1.0
# windspeed       8.662311
# pressure      998.355778
# waveheight      1.495402
# Name: 8865, dtype: float64, Predicted=1.0
# windspeed       12.30
# pressure      1004.30
# waveheight       1.95
# Name: 2268, dtype: float64, Predicted=1.0
# windspeed       11.70
# pressure      1013.30
# waveheight       1.58
# Name: 3858, dtype: float64, Predicted=1.0
# windspeed      17.227261
# pressure      976.414086
# waveheight      5.735982
# Name: 8362, dtype: float64, Predicted=1.0
# windspeed      16.090852
# pressure      959.468095
# waveheight      6.246638
# Name: 6244, dtype: float64, Predicted=1.0
# windspeed        9.10
# pressure      1017.80
# waveheight       2.05
# Name: 2685, dtype: float64, Predicted=1.0
# windspeed       9.861642
# pressure      998.226851
# waveheight      2.340027
# Name: 6179, dtype: float64, Predicted=1.0
# windspeed      10.187649
# pressure      998.236378
# waveheight      2.548832
# Name: 6454, dtype: float64, Predicted=1.0
# windspeed      10.157156
# pressure      998.021383
# waveheight      3.150710
# Name: 9911, dtype: float64, Predicted=1.0
# windspeed       14.40
# pressure      1014.00
# waveheight       1.94
# Name: 2201, dtype: float64, Predicted=1.0
# windspeed       12.40
# pressure      1004.00
# waveheight       1.99
# Name: 2516, dtype: float64, Predicted=1.0
# windspeed       8.073577
# pressure      999.086789
# waveheight      2.552913
# Name: 8870, dtype: float64, Predicted=1.0
# windspeed       6.663663
# pressure      998.511224
# waveheight      7.496129
# Name: 9071, dtype: float64, Predicted=1.0
# windspeed       9.693748
# pressure      987.590589
# waveheight      5.935980
# Name: 9081, dtype: float64, Predicted=1.0
# windspeed       11.50
# pressure      1014.30
# waveheight       1.87
# Name: 1033, dtype: float64, Predicted=1.0
# windspeed       10.60
# pressure      1021.80
# waveheight       1.89
# Name: 4423, dtype: float64, Predicted=1.0
# windspeed      14.902887
# pressure      972.712075
# waveheight      4.340945
# Name: 8195, dtype: float64, Predicted=1.0
# windspeed       13.90
# pressure      1008.90
# waveheight       2.04
# Name: 3777, dtype: float64, Predicted=1.0
# windspeed      12.372222
# pressure      996.469445
# waveheight      2.992778
# Name: 10084, dtype: float64, Predicted=1.0
# windspeed      15.496511
# pressure      992.175000
# waveheight      2.855407
# Name: 7177, dtype: float64, Predicted=1.0
# windspeed       6.863416
# pressure      990.542279
# waveheight      5.544327
# Name: 7328, dtype: float64, Predicted=1.0
# windspeed      15.128248
# pressure      992.206232
# waveheight      2.587167
# Name: 6939, dtype: float64, Predicted=1.0
# windspeed       9.295167
# pressure      996.746375
# waveheight      0.876838
# Name: 7222, dtype: float64, Predicted=1.0
# windspeed      11.698281
# pressure      995.318436
# waveheight      9.000000
# Name: 6283, dtype: float64, Predicted=1.0
# windspeed      16.496052
# pressure      964.677814
# waveheight      6.142444
# Name: 11237, dtype: float64, Predicted=1.0
# windspeed       8.649125
# pressure      999.001751
# waveheight      1.452631
# Name: 8040, dtype: float64, Predicted=1.0
# windspeed      14.927979
# pressure      995.793070
# waveheight      3.823601
# Name: 6576, dtype: float64, Predicted=1.0
# windspeed      16.8
# pressure      990.7
# waveheight      2.9
# Name: 5858, dtype: float64, Predicted=1.0
# windspeed      14.100000
# pressure      993.760163
# waveheight      2.601759
# Name: 6541, dtype: float64, Predicted=1.0
# windspeed       9.066805
# pressure      998.233609
# waveheight      6.132740
# Name: 9054, dtype: float64, Predicted=1.0
# windspeed      11.890977
# pressure      996.640351
# waveheight      2.342957
# Name: 11557, dtype: float64, Predicted=1.0
# windspeed       8.821377
# pressure      997.578623
# waveheight      4.932517
# Name: 6597, dtype: float64, Predicted=1.0
# windspeed       8.358517
# pressure      996.975981
# waveheight      1.927990
# Name: 10630, dtype: float64, Predicted=1.0
# windspeed       9.005224
# pressure      999.649052
# waveheight      1.771946
# Name: 11707, dtype: float64, Predicted=1.0
# windspeed       8.124618
# pressure      997.572325
# waveheight      1.710306
# Name: 9611, dtype: float64, Predicted=1.0
# windspeed      13.660074
# pressure      993.553358
# waveheight      4.939940
# Name: 10711, dtype: float64, Predicted=1.0
# windspeed      14.339919
# pressure      996.902619
# waveheight      3.583085
# Name: 10993, dtype: float64, Predicted=1.0
# windspeed      15.339951
# pressure      983.246090
# waveheight      3.713381
# Name: 7554, dtype: float64, Predicted=1.0
# windspeed       13.20
# pressure      1001.20
# waveheight       1.67
# Name: 627, dtype: float64, Predicted=1.0
# windspeed       9.070251
# pressure      999.296601
# waveheight      1.799660
# Name: 11348, dtype: float64, Predicted=1.0
# windspeed       8.756659
# pressure      998.348248
# waveheight      5.525817
# Name: 10892, dtype: float64, Predicted=1.0
# windspeed       10.00
# pressure      1013.10
# waveheight       1.11
# Name: 2932, dtype: float64, Predicted=1.0
# windspeed       15.60
# pressure      1018.40
# waveheight       3.24
# Name: 831, dtype: float64, Predicted=1.0
# windspeed       12.0
# pressure      1009.2
# waveheight       9.0
# Name: 304, dtype: float64, Predicted=1.0
# windspeed       8.541106
# pressure      997.831591
# waveheight      2.376871
# Name: 9859, dtype: float64, Predicted=1.0
# windspeed      15.017003
# pressure      999.458218
# waveheight      3.034624
# Name: 11402, dtype: float64, Predicted=1.0
# windspeed       7.024731
# pressure      999.544946
# waveheight      3.051355
# Name: 8911, dtype: float64, Predicted=1.0
# windspeed       8.987686
# pressure      997.203284
# waveheight      2.140000
# Name: 11130, dtype: float64, Predicted=1.0
# windspeed       9.168311
# pressure      995.099013
# waveheight      2.649803
# Name: 6935, dtype: float64, Predicted=1.0
# windspeed       11.90
# pressure      1022.70
# waveheight       1.69
# Name: 5366, dtype: float64, Predicted=1.0
# windspeed       5.594044
# pressure      998.427660
# waveheight      6.080555
# Name: 10798, dtype: float64, Predicted=1.0
# windspeed       13.70
# pressure      1007.00
# waveheight       2.03
# Name: 5920, dtype: float64, Predicted=1.0
# windspeed       8.135463
# pressure      999.178611
# waveheight      1.233287
# Name: 10542, dtype: float64, Predicted=1.0
# windspeed      13.408444
# pressure      992.030083
# waveheight      3.029394
# Name: 8267, dtype: float64, Predicted=1.0
# windspeed      13.486746
# pressure      997.673637
# waveheight      2.393359
# Name: 11214, dtype: float64, Predicted=1.0
# windspeed      15.744584
# pressure      993.946676
# waveheight      7.999535
# Name: 11228, dtype: float64, Predicted=1.0
# windspeed      10.584932
# pressure      994.556105
# waveheight      2.527636
# Name: 7309, dtype: float64, Predicted=1.0
# windspeed       8.459520
# pressure      999.461919
# waveheight      1.272129
# Name: 7028, dtype: float64, Predicted=1.0
# windspeed       10.20
# pressure      1017.10
# waveheight       2.24
# Name: 5578, dtype: float64, Predicted=1.0
# windspeed       8.617682
# pressure      999.113010
# waveheight      1.492419
# Name: 8009, dtype: float64, Predicted=1.0
# windspeed       7.742578
# pressure      997.493872
# waveheight      2.088452
# Name: 10494, dtype: float64, Predicted=1.0
# windspeed       7.801052
# pressure      996.827913
# waveheight      1.577735
# Name: 11190, dtype: float64, Predicted=1.0
# windspeed      12.70
# pressure      998.00
# waveheight      2.47
# Name: 137, dtype: float64, Predicted=1.0
# windspeed      11.443129
# pressure      995.513415
# waveheight      2.716421
# Name: 7792, dtype: float64, Predicted=1.0
# windspeed       8.619157
# pressure      999.265955
# waveheight      1.583202
# Name: 8453, dtype: float64, Predicted=1.0
# windspeed        6.9
# pressure      1023.6
# waveheight       9.0
# Name: 4139, dtype: float64, Predicted=1.0

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.81

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_pred, y_test)
names = np.unique(y_pred)
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False,xticklabels=names, yticklabels=names)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.show()

# %%
df_b8_logit = df_b8_init[keep_col]
y2=df_b8_init['possibility']

# %%
y_pred2 = logreg.predict(df_b8_logit)
for i in range(len(df_b8_logit)):
    if(df_b8_logit.iloc[i]['pressure']<1000):
        print("%s, Predicted=%s" % (df_b8_logit.iloc[i], y_pred2[i]))
# Out:
# windspeed       2.60
# pressure      999.60
# waveheight      0.34
# Name: 152, dtype: float64, Predicted=0.0
# windspeed       2.50
# pressure      999.00
# waveheight      0.31
# Name: 153, dtype: float64, Predicted=0.0
# windspeed       3.70
# pressure      998.60
# waveheight      0.34
# Name: 154, dtype: float64, Predicted=0.0
# windspeed       4.30
# pressure      998.10
# waveheight      0.34
# Name: 155, dtype: float64, Predicted=0.0
# windspeed       4.90
# pressure      997.80
# waveheight      0.34
# Name: 156, dtype: float64, Predicted=0.0
# windspeed       5.00
# pressure      997.30
# waveheight      0.34
# Name: 157, dtype: float64, Predicted=0.0
# windspeed       5.40
# pressure      997.00
# waveheight      0.39
# Name: 158, dtype: float64, Predicted=0.0
# windspeed       6.70
# pressure      996.50
# waveheight      0.46
# Name: 159, dtype: float64, Predicted=0.0
# windspeed       6.90
# pressure      995.70
# waveheight      0.53
# Name: 160, dtype: float64, Predicted=0.0
# windspeed       7.30
# pressure      994.90
# waveheight      0.59
# Name: 161, dtype: float64, Predicted=0.0
# windspeed       4.40
# pressure      994.20
# waveheight      0.69
# Name: 162, dtype: float64, Predicted=0.0
# windspeed       7.80
# pressure      993.70
# waveheight      0.64
# Name: 163, dtype: float64, Predicted=1.0
# windspeed       5.40
# pressure      994.00
# waveheight      0.74
# Name: 164, dtype: float64, Predicted=0.0
# windspeed       7.30
# pressure      994.30
# waveheight      0.66
# Name: 165, dtype: float64, Predicted=0.0
# windspeed       7.30
# pressure      994.50
# waveheight      0.75
# Name: 166, dtype: float64, Predicted=0.0
# windspeed       7.80
# pressure      994.90
# waveheight      0.83
# Name: 167, dtype: float64, Predicted=1.0
# windspeed       7.80
# pressure      995.40
# waveheight      0.72
# Name: 168, dtype: float64, Predicted=0.0
# windspeed       8.40
# pressure      995.80
# waveheight      0.76
# Name: 169, dtype: float64, Predicted=1.0
# windspeed       7.80
# pressure      996.20
# waveheight      0.73
# Name: 170, dtype: float64, Predicted=0.0
# windspeed       8.40
# pressure      996.00
# waveheight      0.74
# Name: 171, dtype: float64, Predicted=1.0
# windspeed       8.6
# pressure      996.1
# waveheight      0.8
# Name: 172, dtype: float64, Predicted=1.0
# windspeed       7.00
# pressure      996.30
# waveheight      0.84
# Name: 173, dtype: float64, Predicted=0.0
# windspeed       6.40
# pressure      996.40
# waveheight      0.74
# Name: 174, dtype: float64, Predicted=0.0
# windspeed       4.90
# pressure      996.50
# waveheight      0.67
# Name: 175, dtype: float64, Predicted=0.0
# windspeed       4.60
# pressure      996.40
# waveheight      0.71
# Name: 176, dtype: float64, Predicted=0.0
# windspeed       3.30
# pressure      996.40
# waveheight      0.66
# Name: 177, dtype: float64, Predicted=0.0
# windspeed       2.90
# pressure      996.40
# waveheight      0.61
# Name: 178, dtype: float64, Predicted=0.0
# windspeed       2.50
# pressure      996.60
# waveheight      0.57
# Name: 179, dtype: float64, Predicted=0.0
# windspeed       2.60
# pressure      996.50
# waveheight      0.59
# Name: 180, dtype: float64, Predicted=0.0
# windspeed       1.8
# pressure      996.7
# waveheight      0.6
# Name: 181, dtype: float64, Predicted=0.0
# windspeed       2.50
# pressure      996.70
# waveheight      0.66
# Name: 182, dtype: float64, Predicted=0.0
# windspeed       1.50
# pressure      996.90
# waveheight      0.63
# Name: 183, dtype: float64, Predicted=0.0
# windspeed       0.70
# pressure      996.40
# waveheight      0.69
# Name: 184, dtype: float64, Predicted=0.0
# windspeed       1.90
# pressure      995.90
# waveheight      0.66
# Name: 185, dtype: float64, Predicted=0.0
# windspeed       1.60
# pressure      995.60
# waveheight      0.62
# Name: 186, dtype: float64, Predicted=0.0
# windspeed       3.8
# pressure      995.1
# waveheight      0.6
# Name: 187, dtype: float64, Predicted=0.0
# windspeed       4.20
# pressure      995.10
# waveheight      0.64
# Name: 188, dtype: float64, Predicted=0.0
# windspeed       5.60
# pressure      995.60
# waveheight      0.68
# Name: 189, dtype: float64, Predicted=0.0
# windspeed       9.40
# pressure      995.80
# waveheight      0.84
# Name: 190, dtype: float64, Predicted=1.0
# windspeed       8.70
# pressure      996.30
# waveheight      0.96
# Name: 191, dtype: float64, Predicted=1.0
# windspeed       8.60
# pressure      997.20
# waveheight      0.92
# Name: 192, dtype: float64, Predicted=1.0
# windspeed       9.20
# pressure      997.80
# waveheight      0.98
# Name: 193, dtype: float64, Predicted=1.0
# windspeed      10.50
# pressure      998.00
# waveheight      1.02
# Name: 194, dtype: float64, Predicted=1.0
# windspeed      11.00
# pressure      997.90
# waveheight      1.11
# Name: 195, dtype: float64, Predicted=1.0
# windspeed      11.10
# pressure      997.90
# waveheight      1.21
# Name: 196, dtype: float64, Predicted=1.0
# windspeed      11.80
# pressure      998.00
# waveheight      1.26
# Name: 197, dtype: float64, Predicted=1.0
# windspeed      11.90
# pressure      998.60
# waveheight      1.25
# Name: 198, dtype: float64, Predicted=1.0
# windspeed      12.8
# pressure      999.7
# waveheight      1.3
# Name: 199, dtype: float64, Predicted=1.0
# windspeed       1.50
# pressure      998.60
# waveheight      0.74
# Name: 490, dtype: float64, Predicted=0.0
# windspeed       3.00
# pressure      997.80
# waveheight      0.69
# Name: 491, dtype: float64, Predicted=0.0
# windspeed      10.30
# pressure      997.90
# waveheight      0.73
# Name: 492, dtype: float64, Predicted=1.0
# windspeed       8.00
# pressure      998.40
# waveheight      0.94
# Name: 493, dtype: float64, Predicted=1.0
# windspeed      13.60
# pressure      999.20
# waveheight      1.03
# Name: 494, dtype: float64, Predicted=1.0
# windspeed      14.60
# pressure      997.60
# waveheight      2.37
# Name: 624, dtype: float64, Predicted=1.0
# windspeed      14.70
# pressure      996.50
# waveheight      2.59
# Name: 625, dtype: float64, Predicted=1.0
# windspeed      12.70
# pressure      997.00
# waveheight      2.69
# Name: 626, dtype: float64, Predicted=1.0
# windspeed      13.80
# pressure      995.60
# waveheight      2.88
# Name: 627, dtype: float64, Predicted=1.0
# windspeed      13.20
# pressure      998.20
# waveheight      2.78
# Name: 628, dtype: float64, Predicted=1.0
# windspeed      13.80
# pressure      997.90
# waveheight      2.84
# Name: 629, dtype: float64, Predicted=1.0
# windspeed      11.90
# pressure      999.10
# waveheight      2.56
# Name: 630, dtype: float64, Predicted=1.0
# windspeed       5.00
# pressure      999.30
# waveheight      0.74
# Name: 861, dtype: float64, Predicted=0.0
# windspeed       3.40
# pressure      997.40
# waveheight      0.85
# Name: 862, dtype: float64, Predicted=0.0
# windspeed       6.50
# pressure      995.60
# waveheight      0.92
# Name: 863, dtype: float64, Predicted=0.0
# windspeed       8.80
# pressure      993.70
# waveheight      1.01
# Name: 864, dtype: float64, Predicted=1.0
# windspeed      11.40
# pressure      993.70
# waveheight      1.24
# Name: 865, dtype: float64, Predicted=1.0
# windspeed      11.00
# pressure      994.80
# waveheight      1.83
# Name: 866, dtype: float64, Predicted=1.0
# windspeed      11.70
# pressure      995.80
# waveheight      2.05
# Name: 867, dtype: float64, Predicted=1.0
# windspeed      12.60
# pressure      997.20
# waveheight      1.86
# Name: 868, dtype: float64, Predicted=1.0
# windspeed      12.40
# pressure      998.10
# waveheight      1.91
# Name: 869, dtype: float64, Predicted=1.0
# windspeed      12.90
# pressure      999.30
# waveheight      1.87
# Name: 870, dtype: float64, Predicted=1.0
# windspeed       7.80
# pressure      999.80
# waveheight      1.68
# Name: 1070, dtype: float64, Predicted=1.0
# windspeed       5.90
# pressure      998.90
# waveheight      1.63
# Name: 1071, dtype: float64, Predicted=0.0
# windspeed       7.40
# pressure      997.90
# waveheight      1.54
# Name: 1072, dtype: float64, Predicted=0.0
# windspeed       8.5
# pressure      997.1
# waveheight      1.6
# Name: 1073, dtype: float64, Predicted=1.0
# windspeed       7.70
# pressure      996.30
# waveheight      1.66
# Name: 1074, dtype: float64, Predicted=1.0
# windspeed       9.00
# pressure      996.20
# waveheight      1.68
# Name: 1075, dtype: float64, Predicted=1.0
# windspeed       9.00
# pressure      997.40
# waveheight      1.69
# Name: 1076, dtype: float64, Predicted=1.0
# windspeed      14.20
# pressure      998.40
# waveheight      1.98
# Name: 1077, dtype: float64, Predicted=1.0
# windspeed      11.60
# pressure      998.30
# waveheight      1.17
# Name: 1330, dtype: float64, Predicted=1.0
# windspeed      16.40
# pressure      994.90
# waveheight      1.94
# Name: 1331, dtype: float64, Predicted=1.0
# windspeed      15.00
# pressure      993.10
# waveheight      2.65
# Name: 1332, dtype: float64, Predicted=1.0
# windspeed      14.50
# pressure      991.10
# waveheight      3.26
# Name: 1333, dtype: float64, Predicted=1.0
# windspeed      14.10
# pressure      989.60
# waveheight      3.14
# Name: 1334, dtype: float64, Predicted=1.0
# windspeed      13.00
# pressure      988.30
# waveheight      2.91
# Name: 1335, dtype: float64, Predicted=1.0
# windspeed       6.10
# pressure      990.10
# waveheight      2.85
# Name: 1336, dtype: float64, Predicted=0.0
# windspeed       6.00
# pressure      990.60
# waveheight      3.31
# Name: 1337, dtype: float64, Predicted=0.0
# windspeed      15.7
# pressure      992.0
# waveheight      3.0
# Name: 1338, dtype: float64, Predicted=1.0
# windspeed      17.00
# pressure      995.80
# waveheight      2.97
# Name: 1339, dtype: float64, Predicted=1.0
# windspeed      12.10
# pressure      998.60
# waveheight      2.46
# Name: 1406, dtype: float64, Predicted=1.0
# windspeed      11.00
# pressure      997.70
# waveheight      2.61
# Name: 1407, dtype: float64, Predicted=1.0
# windspeed      10.7
# pressure      998.2
# waveheight      2.3
# Name: 1408, dtype: float64, Predicted=1.0
# windspeed       9.40
# pressure      998.90
# waveheight      2.19
# Name: 1409, dtype: float64, Predicted=1.0
# windspeed      12.20
# pressure      999.50
# waveheight      2.55
# Name: 1561, dtype: float64, Predicted=1.0
# windspeed      11.00
# pressure      998.10
# waveheight      2.53
# Name: 1562, dtype: float64, Predicted=1.0
# windspeed      10.10
# pressure      997.10
# waveheight      2.72
# Name: 1563, dtype: float64, Predicted=1.0
# windspeed       7.60
# pressure      996.60
# waveheight      2.72
# Name: 1564, dtype: float64, Predicted=1.0
# windspeed       8.20
# pressure      996.20
# waveheight      2.74
# Name: 1565, dtype: float64, Predicted=1.0
# windspeed      11.90
# pressure      998.20
# waveheight      2.91
# Name: 1566, dtype: float64, Predicted=1.0
# windspeed       9.20
# pressure      999.40
# waveheight      1.96
# Name: 1969, dtype: float64, Predicted=1.0
# windspeed       9.70
# pressure      999.10
# waveheight      1.94
# Name: 1970, dtype: float64, Predicted=1.0
# windspeed       9.20
# pressure      999.70
# waveheight      1.91
# Name: 1971, dtype: float64, Predicted=1.0
# windspeed      10.50
# pressure      999.80
# waveheight      1.85
# Name: 1973, dtype: float64, Predicted=1.0
# windspeed       9.70
# pressure      999.70
# waveheight      2.06
# Name: 2161, dtype: float64, Predicted=1.0
# windspeed       9.80
# pressure      997.90
# waveheight      2.26
# Name: 2162, dtype: float64, Predicted=1.0
# windspeed       8.40
# pressure      997.50
# waveheight      2.32
# Name: 2163, dtype: float64, Predicted=1.0
# windspeed       7.50
# pressure      996.60
# waveheight      2.39
# Name: 2164, dtype: float64, Predicted=1.0
# windspeed       8.40
# pressure      995.80
# waveheight      2.48
# Name: 2165, dtype: float64, Predicted=1.0
# windspeed       8.10
# pressure      995.10
# waveheight      2.21
# Name: 2166, dtype: float64, Predicted=1.0
# windspeed       7.10
# pressure      995.10
# waveheight      2.15
# Name: 2167, dtype: float64, Predicted=1.0
# windspeed       6.80
# pressure      995.00
# waveheight      2.08
# Name: 2168, dtype: float64, Predicted=0.0
# windspeed       7.20
# pressure      994.80
# waveheight      2.15
# Name: 2169, dtype: float64, Predicted=1.0
# windspeed       6.60
# pressure      994.90
# waveheight      1.95
# Name: 2170, dtype: float64, Predicted=0.0
# windspeed       7.40
# pressure      994.40
# waveheight      1.77
# Name: 2171, dtype: float64, Predicted=1.0
# windspeed       7.30
# pressure      993.80
# waveheight      1.64
# Name: 2172, dtype: float64, Predicted=1.0
# windspeed       8.60
# pressure      993.20
# waveheight      1.63
# Name: 2173, dtype: float64, Predicted=1.0
# windspeed       7.70
# pressure      992.60
# waveheight      1.48
# Name: 2174, dtype: float64, Predicted=1.0
# windspeed       8.50
# pressure      992.60
# waveheight      1.46
# Name: 2175, dtype: float64, Predicted=1.0
# windspeed       8.20
# pressure      992.80
# waveheight      1.29
# Name: 2176, dtype: float64, Predicted=1.0
# windspeed       9.30
# pressure      993.60
# waveheight      1.31
# Name: 2177, dtype: float64, Predicted=1.0
# windspeed       4.40
# pressure      994.60
# waveheight      1.26
# Name: 2178, dtype: float64, Predicted=0.0
# windspeed       4.60
# pressure      995.20
# waveheight      1.06
# Name: 2179, dtype: float64, Predicted=0.0
# windspeed       6.80
# pressure      995.70
# waveheight      1.12
# Name: 2180, dtype: float64, Predicted=0.0
# windspeed      10.50
# pressure      996.30
# waveheight      1.07
# Name: 2181, dtype: float64, Predicted=1.0
# windspeed       8.90
# pressure      996.90
# waveheight      1.17
# Name: 2182, dtype: float64, Predicted=1.0
# windspeed       9.60
# pressure      997.20
# waveheight      1.06
# Name: 2183, dtype: float64, Predicted=1.0
# windspeed      10.40
# pressure      997.20
# waveheight      1.12
# Name: 2184, dtype: float64, Predicted=1.0
# windspeed      10.2
# pressure      997.2
# waveheight      1.2
# Name: 2185, dtype: float64, Predicted=1.0
# windspeed      10.70
# pressure      997.20
# waveheight      1.15
# Name: 2186, dtype: float64, Predicted=1.0
# windspeed      10.60
# pressure      997.30
# waveheight      1.23
# Name: 2187, dtype: float64, Predicted=1.0
# windspeed       9.80
# pressure      997.80
# waveheight      1.12
# Name: 2188, dtype: float64, Predicted=1.0
# windspeed       9.40
# pressure      998.60
# waveheight      1.11
# Name: 2189, dtype: float64, Predicted=1.0
# windspeed      10.60
# pressure      999.10
# waveheight      1.13
# Name: 2190, dtype: float64, Predicted=1.0
# windspeed       5.30
# pressure      999.70
# waveheight      0.91
# Name: 2196, dtype: float64, Predicted=0.0
# windspeed       5.7
# pressure      999.2
# waveheight      0.9
# Name: 2197, dtype: float64, Predicted=0.0
# windspeed       5.90
# pressure      998.90
# waveheight      0.85
# Name: 2198, dtype: float64, Predicted=0.0
# windspeed       6.00
# pressure      998.70
# waveheight      0.83
# Name: 2199, dtype: float64, Predicted=0.0
# windspeed       6.4
# pressure      998.8
# waveheight      0.8
# Name: 2200, dtype: float64, Predicted=0.0
# windspeed       6.3
# pressure      999.4
# waveheight      0.8
# Name: 2201, dtype: float64, Predicted=0.0
# windspeed       8.60
# pressure      999.60
# waveheight      1.79
# Name: 2249, dtype: float64, Predicted=1.0
# windspeed      10.10
# pressure      999.00
# waveheight      2.14
# Name: 2250, dtype: float64, Predicted=1.0
# windspeed       9.80
# pressure      998.50
# waveheight      2.06
# Name: 2251, dtype: float64, Predicted=1.0
# windspeed       9.90
# pressure      997.80
# waveheight      2.21
# Name: 2252, dtype: float64, Predicted=1.0
# windspeed      10.40
# pressure      997.60
# waveheight      2.01
# Name: 2253, dtype: float64, Predicted=1.0
# windspeed      12.90
# pressure      996.70
# waveheight      2.22
# Name: 2254, dtype: float64, Predicted=1.0
# windspeed      12.9
# pressure      996.5
# waveheight      2.7
# Name: 2255, dtype: float64, Predicted=1.0
# windspeed      12.40
# pressure      996.20
# waveheight      3.29
# Name: 2256, dtype: float64, Predicted=1.0
# windspeed      12.80
# pressure      995.90
# waveheight      2.89
# Name: 2257, dtype: float64, Predicted=1.0
# windspeed      12.70
# pressure      994.80
# waveheight      3.03
# Name: 2258, dtype: float64, Predicted=1.0
# windspeed      12.10
# pressure      994.40
# waveheight      3.14
# Name: 2259, dtype: float64, Predicted=1.0
# windspeed      14.1
# pressure      993.6
# waveheight      3.2
# Name: 2260, dtype: float64, Predicted=1.0
# windspeed      13.40
# pressure      992.90
# waveheight      2.79
# Name: 2261, dtype: float64, Predicted=1.0
# windspeed      13.60
# pressure      991.70
# waveheight      3.27
# Name: 2262, dtype: float64, Predicted=1.0
# windspeed      12.4
# pressure      991.6
# waveheight      3.0
# Name: 2263, dtype: float64, Predicted=1.0
# windspeed      14.30
# pressure      990.50
# waveheight      3.12
# Name: 2264, dtype: float64, Predicted=1.0
# windspeed      12.70
# pressure      989.80
# waveheight      3.14
# Name: 2265, dtype: float64, Predicted=1.0
# windspeed      12.90
# pressure      990.20
# waveheight      3.12
# Name: 2266, dtype: float64, Predicted=1.0
# windspeed      14.00
# pressure      989.40
# waveheight      2.98
# Name: 2267, dtype: float64, Predicted=1.0
# windspeed       9.60
# pressure      992.20
# waveheight      2.52
# Name: 2268, dtype: float64, Predicted=1.0
# windspeed      11.40
# pressure      993.80
# waveheight      2.38
# Name: 2269, dtype: float64, Predicted=1.0
# windspeed      13.20
# pressure      995.40
# waveheight      2.19
# Name: 2270, dtype: float64, Predicted=1.0
# windspeed       9.00
# pressure      996.10
# waveheight      1.99
# Name: 2271, dtype: float64, Predicted=1.0
# windspeed      10.90
# pressure      998.00
# waveheight      1.89
# Name: 2272, dtype: float64, Predicted=1.0
# windspeed      14.50
# pressure      999.60
# waveheight      3.07
# Name: 2543, dtype: float64, Predicted=1.0
# windspeed      14.50
# pressure      997.10
# waveheight      3.27
# Name: 2544, dtype: float64, Predicted=1.0
# windspeed      12.40
# pressure      996.60
# waveheight      3.62
# Name: 2545, dtype: float64, Predicted=1.0
# windspeed       5.60
# pressure      997.50
# waveheight      3.61
# Name: 2546, dtype: float64, Predicted=0.0
# windspeed       5.10
# pressure      998.00
# waveheight      2.95
# Name: 2547, dtype: float64, Predicted=0.0
# windspeed       5.30
# pressure      998.70
# waveheight      2.84
# Name: 2548, dtype: float64, Predicted=0.0
# windspeed       7.70
# pressure      999.70
# waveheight      3.04
# Name: 2549, dtype: float64, Predicted=1.0
# windspeed       2.7
# pressure      999.9
# waveheight      1.1
# Name: 5256, dtype: float64, Predicted=0.0
# windspeed       3.00
# pressure      999.40
# waveheight      1.11
# Name: 5257, dtype: float64, Predicted=0.0
# windspeed       3.80
# pressure      998.90
# waveheight      1.04
# Name: 5258, dtype: float64, Predicted=0.0
# windspeed       4.30
# pressure      999.00
# waveheight      0.95
# Name: 5259, dtype: float64, Predicted=0.0
# windspeed       5.60
# pressure      999.30
# waveheight      1.04
# Name: 5260, dtype: float64, Predicted=0.0
# windspeed       5.90
# pressure      999.70
# waveheight      0.97
# Name: 5261, dtype: float64, Predicted=0.0
# windspeed       5.10
# pressure      999.90
# waveheight      1.05
# Name: 5262, dtype: float64, Predicted=0.0
# windspeed       8.10
# pressure      999.70
# waveheight      0.88
# Name: 5296, dtype: float64, Predicted=0.0
# windspeed       8.0
# pressure      998.6
# waveheight      0.9
# Name: 5297, dtype: float64, Predicted=0.0
# windspeed       7.3
# pressure      998.7
# waveheight      1.0
# Name: 5298, dtype: float64, Predicted=0.0
# windspeed       5.90
# pressure      999.00
# waveheight      1.03
# Name: 5299, dtype: float64, Predicted=0.0
# windspeed       2.30
# pressure      999.30
# waveheight      0.96
# Name: 5300, dtype: float64, Predicted=0.0
# windspeed       3.3
# pressure      999.3
# waveheight      0.9
# Name: 5301, dtype: float64, Predicted=0.0
# windspeed       3.90
# pressure      999.40
# waveheight      0.89
# Name: 5302, dtype: float64, Predicted=0.0
# windspeed       6.10
# pressure      999.30
# waveheight      0.84
# Name: 5303, dtype: float64, Predicted=0.0
# windspeed       6.30
# pressure      999.30
# waveheight      0.99
# Name: 5304, dtype: float64, Predicted=0.0
# windspeed       7.70
# pressure      999.20
# waveheight      1.01
# Name: 5305, dtype: float64, Predicted=0.0
# windspeed       9.40
# pressure      999.00
# waveheight      1.12
# Name: 5306, dtype: float64, Predicted=1.0
# windspeed       8.80
# pressure      999.60
# waveheight      1.14
# Name: 5307, dtype: float64, Predicted=1.0
# windspeed      14.20
# pressure      999.30
# waveheight      2.72
# Name: 5733, dtype: float64, Predicted=1.0
# windspeed      15.40
# pressure      997.20
# waveheight      2.87
# Name: 5734, dtype: float64, Predicted=1.0
# windspeed      18.70
# pressure      991.20
# waveheight      3.98
# Name: 5736, dtype: float64, Predicted=1.0
# windspeed      16.30
# pressure      989.60
# waveheight      4.27
# Name: 5737, dtype: float64, Predicted=1.0
# windspeed      15.80
# pressure      986.20
# waveheight      4.84
# Name: 5738, dtype: float64, Predicted=1.0
# windspeed      17.70
# pressure      983.10
# waveheight      5.21
# Name: 5739, dtype: float64, Predicted=1.0
# windspeed      15.60
# pressure      980.20
# waveheight      5.84
# Name: 5740, dtype: float64, Predicted=1.0
# windspeed      17.80
# pressure      976.40
# waveheight      6.64
# Name: 5741, dtype: float64, Predicted=1.0
# windspeed      19.5
# pressure      972.2
# waveheight      7.1
# Name: 5742, dtype: float64, Predicted=1.0
# windspeed      19.70
# pressure      968.20
# waveheight      7.24
# Name: 5743, dtype: float64, Predicted=1.0
# windspeed      20.00
# pressure      968.00
# waveheight      7.95
# Name: 5744, dtype: float64, Predicted=1.0
# windspeed      15.70
# pressure      972.00
# waveheight      5.91
# Name: 5745, dtype: float64, Predicted=1.0
# windspeed      13.10
# pressure      975.70
# waveheight      5.12
# Name: 5746, dtype: float64, Predicted=1.0
# windspeed      12.10
# pressure      978.60
# waveheight      4.33
# Name: 5747, dtype: float64, Predicted=1.0
# windspeed      12.1
# pressure      981.1
# waveheight      4.1
# Name: 5748, dtype: float64, Predicted=1.0
# windspeed      12.50
# pressure      983.40
# waveheight      2.96
# Name: 5749, dtype: float64, Predicted=1.0
# windspeed      15.90
# pressure      986.50
# waveheight      3.14
# Name: 5750, dtype: float64, Predicted=1.0
# windspeed      15.70
# pressure      988.60
# waveheight      2.91
# Name: 5751, dtype: float64, Predicted=1.0
# windspeed      18.10
# pressure      990.50
# waveheight      3.16
# Name: 5752, dtype: float64, Predicted=1.0
# windspeed      16.20
# pressure      994.10
# waveheight      3.09
# Name: 5753, dtype: float64, Predicted=1.0
# windspeed      18.20
# pressure      996.70
# waveheight      2.97
# Name: 5754, dtype: float64, Predicted=1.0
# windspeed      15.20
# pressure      999.70
# waveheight      2.66
# Name: 5755, dtype: float64, Predicted=1.0
# windspeed       5.90
# pressure      999.70
# waveheight      1.12
# Name: 6069, dtype: float64, Predicted=0.0
# windspeed       6.10
# pressure      999.40
# waveheight      1.08
# Name: 6070, dtype: float64, Predicted=0.0
# windspeed       5.50
# pressure      997.90
# waveheight      1.15
# Name: 6071, dtype: float64, Predicted=0.0
# windspeed       6.00
# pressure      997.00
# waveheight      1.23
# Name: 6072, dtype: float64, Predicted=0.0
# windspeed       7.90
# pressure      995.70
# waveheight      1.22
# Name: 6073, dtype: float64, Predicted=1.0
# windspeed       8.20
# pressure      995.10
# waveheight      1.37
# Name: 6074, dtype: float64, Predicted=1.0
# windspeed       9.40
# pressure      994.70
# waveheight      1.47
# Name: 6075, dtype: float64, Predicted=1.0
# windspeed       9.30
# pressure      995.60
# waveheight      1.64
# Name: 6076, dtype: float64, Predicted=1.0
# windspeed       8.70
# pressure      996.20
# waveheight      1.61
# Name: 6077, dtype: float64, Predicted=1.0
# windspeed      11.10
# pressure      997.00
# waveheight      1.44
# Name: 6078, dtype: float64, Predicted=1.0
# windspeed       9.80
# pressure      998.20
# waveheight      1.49
# Name: 6079, dtype: float64, Predicted=1.0
# windspeed       9.20
# pressure      999.20
# waveheight      1.56
# Name: 6080, dtype: float64, Predicted=1.0
# windspeed      11.50
# pressure      999.80
# waveheight      1.39
# Name: 6081, dtype: float64, Predicted=1.0
# windspeed      15.6
# pressure      999.2
# waveheight      9.0
# Name: 6193, dtype: float64, Predicted=1.0
# windspeed      13.3
# pressure      999.3
# waveheight      9.0
# Name: 6194, dtype: float64, Predicted=1.0
# windspeed      11.9
# pressure      999.1
# waveheight      9.0
# Name: 6195, dtype: float64, Predicted=1.0
# windspeed       9.9
# pressure      998.9
# waveheight      9.0
# Name: 6196, dtype: float64, Predicted=1.0
# windspeed      10.4
# pressure      998.8
# waveheight      9.0
# Name: 6197, dtype: float64, Predicted=1.0
# windspeed      10.40
# pressure      998.00
# waveheight      2.24
# Name: 6198, dtype: float64, Predicted=1.0
# windspeed       8.4
# pressure      998.1
# waveheight      9.0
# Name: 6199, dtype: float64, Predicted=1.0
# windspeed       6.4
# pressure      997.1
# waveheight      9.0
# Name: 6200, dtype: float64, Predicted=1.0
# windspeed       7.8
# pressure      995.8
# waveheight      9.0
# Name: 6201, dtype: float64, Predicted=1.0
# windspeed      10.00
# pressure      994.70
# waveheight      2.43
# Name: 6202, dtype: float64, Predicted=1.0
# windspeed      10.20
# pressure      994.00
# waveheight      2.48
# Name: 6203, dtype: float64, Predicted=1.0
# windspeed      10.20
# pressure      994.40
# waveheight      2.78
# Name: 6204, dtype: float64, Predicted=1.0
# windspeed       8.20
# pressure      994.50
# waveheight      2.41
# Name: 6205, dtype: float64, Predicted=1.0
# windspeed       9.60
# pressure      994.70
# waveheight      2.42
# Name: 6206, dtype: float64, Predicted=1.0
# windspeed       7.80
# pressure      994.10
# waveheight      2.59
# Name: 6207, dtype: float64, Predicted=1.0
# windspeed       8.50
# pressure      994.10
# waveheight      2.74
# Name: 6208, dtype: float64, Predicted=1.0
# windspeed      10.20
# pressure      994.40
# waveheight      2.83
# Name: 6209, dtype: float64, Predicted=1.0
# windspeed      10.70
# pressure      995.10
# waveheight      2.71
# Name: 6210, dtype: float64, Predicted=1.0
# windspeed      13.70
# pressure      996.10
# waveheight      2.72
# Name: 6211, dtype: float64, Predicted=1.0
# windspeed      14.20
# pressure      997.00
# waveheight      2.87
# Name: 6212, dtype: float64, Predicted=1.0
# windspeed      13.10
# pressure      997.90
# waveheight      3.14
# Name: 6213, dtype: float64, Predicted=1.0
# windspeed      11.60
# pressure      998.50
# waveheight      3.25
# Name: 6214, dtype: float64, Predicted=1.0
# windspeed      11.4
# pressure      998.7
# waveheight      3.0
# Name: 6215, dtype: float64, Predicted=1.0
# windspeed      11.40
# pressure      998.80
# waveheight      3.02
# Name: 6216, dtype: float64, Predicted=1.0
# windspeed      11.9
# pressure      999.2
# waveheight      2.9
# Name: 6217, dtype: float64, Predicted=1.0
# windspeed      12.70
# pressure      999.60
# waveheight      2.79
# Name: 6218, dtype: float64, Predicted=1.0
# windspeed       3.50
# pressure      999.70
# waveheight      1.16
# Name: 7371, dtype: float64, Predicted=0.0
# windspeed       3.4
# pressure      998.2
# waveheight      1.4
# Name: 7372, dtype: float64, Predicted=0.0
# windspeed       2.80
# pressure      996.70
# waveheight      1.55
# Name: 7373, dtype: float64, Predicted=0.0
# windspeed       1.50
# pressure      995.60
# waveheight      1.67
# Name: 7374, dtype: float64, Predicted=0.0
# windspeed      13.0
# pressure      993.3
# waveheight      1.6
# Name: 7375, dtype: float64, Predicted=1.0
# windspeed      16.40
# pressure      994.40
# waveheight      1.88
# Name: 7376, dtype: float64, Predicted=1.0
# windspeed      15.00
# pressure      994.60
# waveheight      2.13
# Name: 7377, dtype: float64, Predicted=1.0
# windspeed       6.202014
# pressure      999.200000
# waveheight      2.180000
# Name: 7378, dtype: float64, Predicted=0.0
# windspeed      13.30
# pressure      998.90
# waveheight      1.55
# Name: 7850, dtype: float64, Predicted=1.0
# windspeed      15.30
# pressure      996.10
# waveheight      2.11
# Name: 7851, dtype: float64, Predicted=1.0
# windspeed      16.60
# pressure      993.50
# waveheight      2.83
# Name: 7852, dtype: float64, Predicted=1.0
# windspeed      16.60
# pressure      993.00
# waveheight      3.56
# Name: 7853, dtype: float64, Predicted=1.0
# windspeed      11.80
# pressure      994.20
# waveheight      3.54
# Name: 7854, dtype: float64, Predicted=1.0
# windspeed       9.10
# pressure      995.10
# waveheight      3.62
# Name: 7855, dtype: float64, Predicted=1.0
# windspeed      10.8
# pressure      995.1
# waveheight      3.5
# Name: 7856, dtype: float64, Predicted=1.0
# windspeed       9.90
# pressure      995.60
# waveheight      2.63
# Name: 7857, dtype: float64, Predicted=1.0
# windspeed       8.30
# pressure      996.10
# waveheight      2.87
# Name: 7858, dtype: float64, Predicted=1.0
# windspeed       8.70
# pressure      996.50
# waveheight      2.97
# Name: 7859, dtype: float64, Predicted=1.0
# windspeed       7.20
# pressure      996.40
# waveheight      2.63
# Name: 7860, dtype: float64, Predicted=1.0
# windspeed      11.2
# pressure      996.2
# waveheight      9.0
# Name: 7861, dtype: float64, Predicted=1.0
# windspeed      11.9
# pressure      997.0
# waveheight      2.6
# Name: 7862, dtype: float64, Predicted=1.0
# windspeed      11.70
# pressure      997.40
# waveheight      2.76
# Name: 7863, dtype: float64, Predicted=1.0
# windspeed      11.90
# pressure      998.00
# waveheight      2.54
# Name: 7864, dtype: float64, Predicted=1.0
# windspeed      12.60
# pressure      998.40
# waveheight      2.33
# Name: 7865, dtype: float64, Predicted=1.0
# windspeed      12.3
# pressure      999.1
# waveheight      2.5
# Name: 7866, dtype: float64, Predicted=1.0
# windspeed      13.60
# pressure      999.30
# waveheight      2.32
# Name: 7867, dtype: float64, Predicted=1.0
# windspeed      13.90
# pressure      999.20
# waveheight      2.23
# Name: 7868, dtype: float64, Predicted=1.0
# windspeed      15.10
# pressure      999.70
# waveheight      2.21
# Name: 7869, dtype: float64, Predicted=1.0

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(df_b8_logit, y2)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.83
