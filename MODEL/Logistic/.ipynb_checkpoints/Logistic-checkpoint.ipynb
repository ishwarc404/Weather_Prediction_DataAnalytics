# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import statsmodels.api as sm
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
df_b7_init = pd.read_csv('/Users/shreyabanerjee/DA_proj/clean_csvs/44009_clean.csv')
df_b8_init = pd.read_csv('/Users/shreyabanerjee/DA_proj/clean_csvs/44065_clean.csv')

# %%
def plot_df(df, x,y1, y2, title="", xlabel='Date', dpi=100):
    
    fig = plt.figure(figsize=(15,5))
    ax1 = fig.add_subplot(111)
    ax1.plot(x, y1)
    ax1.set_ylabel('Windspeed')
    #plt.setp(fig, rotation=90)
    plt.xticks(rotation=90)
    ax2 = ax1.twinx()
    ax2.plot(x, y2, 'r-')
    ax2.set_ylabel('Pressure', color='r')
    for tl in ax2.get_yticklabels():
        tl.set_color('r')

# %%
keep_col = ['day','month','datetime','waveperiod','waveheight','WindDir','windspeed','pressure','possibility','hurrthreat']
df_b7 = df_b7_init[keep_col]
df_b8=df_b8_init[keep_col]

# %%
rs_09 = df_b7.loc[ (df_b7['month']==8)] #& ( (df_b7['day']==27) | (df_b7['day']==28) | (df_b7['day']==29) )]rs_09['date'] = rs_09['datetime'].astype('datetime64[ns]')
rs_09['date'] = rs_09['datetime'].astype('datetime64[ns]')
rs_09.head()
plot_df(rs_09, x=rs_09.datetime,y1=rs_09.windspeed, y2=rs_09.pressure, title='Pressure in month of August')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rs_65 = df_b8.loc[ (df_b8['month']==8)]# & ( (df_b8['day']==27) | (df_b8['day']==28) | (df_b8['day']==29) )]
rs_65['date'] = rs_65['datetime'].astype('datetime64[ns]')
rs_65.head()
plot_df(rs_65, x=rs_65.datetime,y1=rs_65.windspeed, y2=rs_65.pressure, title='Pressure in month of August')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x=df_b7['pressure']
y1=df_b7['hurrthreat']
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(111)
ax1.plot(x, y1)
ax1.set_ylabel('pressure')
# Out:
# Text(0, 0.5, 'pressure')

# %%
keep_col = ['day','month','waveperiod','waveheight','WindDir','windspeed','pressure']
X = df_b7_init[keep_col]
y = df_b7_init['hurrthreat']

os = SMOTE(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
columns = X_train.columns
os_data_X,os_data_y=os.fit_sample(X_train, y_train)

os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['hurrthreat'])
# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_X))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['hurrthreat']==0]))
print("Number of subscription",len(os_data_y[os_data_y['hurrthreat']==1]))
print("Proportion of no subscription data in oversampled data is ",len(os_data_y[os_data_y['hurrthreat']==0])/len(os_data_X))
print("Proportion of subscription data in oversampled data is ",len(os_data_y[os_data_y['hurrthreat']==1])/len(os_data_X))
# Out:
# length of oversampled data is  11848
# Number of no subscription in oversampled data 5924
# Number of subscription 5924
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
os_data_X
# Out:
#              day  month  waveperiod  waveheight     WindDir  windspeed  \
# 0      16.000000   11.0    4.330000    0.930000  200.000000   6.800000
# 1      17.000000   12.0    3.780000    1.100000  319.000000   8.900000
# 2       7.000000   10.0    6.090000    0.890000   29.000000   3.700000
# 3      23.000000   10.0    3.750000    0.500000  360.000000   3.700000
# 4      23.000000    5.0    4.090000    1.050000  138.000000   6.100000
# ...          ...    ...         ...         ...         ...        ...
# 11843  26.409705    8.0    4.956781    0.947647   51.487101   3.153563
# 11844  23.000000    8.0    3.901889    0.763524   34.704889   4.010622
# 11845  24.000000    8.0    4.133792    0.498253  142.747198   3.982528
# 11846  30.000000    8.0    6.293113    1.050437   28.620203   4.762846
# 11847  27.000000    8.0    9.000000    9.000000   79.086633   9.582673
#
#           pressure
# 0      1013.000000
# 1      1021.300000
# 2      1031.700000
# 3      1022.900000
# 4      1018.500000
# ...            ...
# 11843  1018.569042
# 11844  1017.670489
# 11845  1018.877696
# 11846  1016.735794
# 11847  1006.982673
#
# [11848 rows x 7 columns]

# %%
os_data_y.head()
# Out:
#    hurrthreat
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
keep_col = ['windspeed','pressure']
df_b7_logit = os_data_X[keep_col]
y1=os_data_y['hurrthreat']

# %%
X_train, x_test, y_train, y_test = train_test_split(df_b7_logit,y1,test_size=0.3, random_state=0)

# %%
logreg = LogisticRegression()

#logit_model=sm.Logit(y_train,X_train.astype(float))

result=logreg.fit(X_train,y_train)
#print(result.summary2())
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.

# %%
#keep_col_new=['pressure']
#new_x= df_b7_init[keep_col_new]
#y1=df_b7_init['hurrthreat']
#X_t, X_tes, y_t, y_tes = train_test_split(new_x, y1, test_size=0.3, random_state=0)

#model.fit(X_t, y_t)
y_pred = logreg.predict(x_test)
x_test.head()
#X_tes.iloc[3]
for i in range(len(x_test)):
    if(x_test.iloc[i]['pressure']<1000):
        print("%s, Predicted=%s" % (x_test.iloc[i], y_pred[i]))
# Out:
# windspeed      1.4
# pressure     997.9
# Name: 1569, dtype: float64, Predicted=0
# windspeed      8.777317
# pressure     999.423912
# Name: 8544, dtype: float64, Predicted=1
# windspeed     17.270665
# pressure     980.386182
# Name: 7465, dtype: float64, Predicted=1
# windspeed     16.553771
# pressure     970.809489
# Name: 7302, dtype: float64, Predicted=1
# windspeed     19.079875
# pressure     991.171034
# Name: 7712, dtype: float64, Predicted=1
# windspeed      6.125145
# pressure     989.749682
# Name: 10901, dtype: float64, Predicted=1
# windspeed     11.024748
# pressure     998.015319
# Name: 10777, dtype: float64, Predicted=1
# windspeed     16.923587
# pressure     983.032648
# Name: 9175, dtype: float64, Predicted=1
# windspeed     11.184533
# pressure     996.874460
# Name: 6719, dtype: float64, Predicted=1
# windspeed     17.358687
# pressure     978.777360
# Name: 6098, dtype: float64, Predicted=1
# windspeed      9.031949
# pressure     999.402999
# Name: 11334, dtype: float64, Predicted=1
# windspeed     16.792093
# pressure     974.469201
# Name: 10269, dtype: float64, Predicted=1
# windspeed     10.4
# pressure     997.8
# Name: 3213, dtype: float64, Predicted=1
# windspeed     16.600000
# pressure     992.511433
# Name: 6433, dtype: float64, Predicted=1
# windspeed     11.3
# pressure     994.8
# Name: 4315, dtype: float64, Predicted=1
# windspeed     17.274970
# pressure     980.353351
# Name: 10258, dtype: float64, Predicted=1
# windspeed     16.644097
# pressure     980.960170
# Name: 6221, dtype: float64, Predicted=1
# windspeed     16.795638
# pressure     990.671645
# Name: 11342, dtype: float64, Predicted=1
# windspeed     12.915898
# pressure     994.901172
# Name: 7166, dtype: float64, Predicted=1
# windspeed      6.950462
# pressure     998.742874
# Name: 8334, dtype: float64, Predicted=1
# windspeed     16.413812
# pressure     988.189781
# Name: 8940, dtype: float64, Predicted=1
# windspeed     14.242926
# pressure     999.913522
# Name: 11401, dtype: float64, Predicted=1
# windspeed     16.4
# pressure     988.1
# Name: 2701, dtype: float64, Predicted=1
# windspeed      9.239078
# pressure     999.651701
# Name: 10057, dtype: float64, Predicted=1
# windspeed      7.5
# pressure     997.6
# Name: 4250, dtype: float64, Predicted=1
# windspeed      7.060946
# pressure     994.241548
# Name: 9516, dtype: float64, Predicted=1
# windspeed      9.593086
# pressure     998.661808
# Name: 8642, dtype: float64, Predicted=1
# windspeed     16.002420
# pressure     958.331114
# Name: 10688, dtype: float64, Predicted=1
# windspeed     14.1
# pressure     995.9
# Name: 39, dtype: float64, Predicted=1
# windspeed     15.82032
# pressure     974.93263
# Name: 11472, dtype: float64, Predicted=1
# windspeed     17.355652
# pressure     979.532119
# Name: 11542, dtype: float64, Predicted=1
# windspeed      9.637780
# pressure     998.828545
# Name: 10605, dtype: float64, Predicted=1
# windspeed     16.038717
# pressure     958.797791
# Name: 6574, dtype: float64, Predicted=1
# windspeed     11.574257
# pressure     993.573887
# Name: 6313, dtype: float64, Predicted=1
# windspeed      7.9
# pressure     999.0
# Name: 541, dtype: float64, Predicted=1
# windspeed     13.380149
# pressure     993.401517
# Name: 8534, dtype: float64, Predicted=1
# windspeed     16.591829
# pressure     989.346889
# Name: 7314, dtype: float64, Predicted=1
# windspeed     16.826381
# pressure     969.484581
# Name: 7902, dtype: float64, Predicted=1
# windspeed     16.945202
# pressure     981.261886
# Name: 10122, dtype: float64, Predicted=1
# windspeed     14.691711
# pressure     976.217603
# Name: 9249, dtype: float64, Predicted=1
# windspeed      9.656061
# pressure     998.532954
# Name: 10263, dtype: float64, Predicted=1
# windspeed     16.513284
# pressure     973.880053
# Name: 8943, dtype: float64, Predicted=1
# windspeed     14.8
# pressure     997.5
# Name: 1869, dtype: float64, Predicted=1
# windspeed     18.220937
# pressure     992.158048
# Name: 7161, dtype: float64, Predicted=1
# windspeed     15.020431
# pressure     971.040565
# Name: 9055, dtype: float64, Predicted=1
# windspeed      9.262177
# pressure     999.859591
# Name: 8720, dtype: float64, Predicted=1
# windspeed     15.820134
# pressure     991.819847
# Name: 8264, dtype: float64, Predicted=1
# windspeed      8.378278
# pressure     999.776908
# Name: 6406, dtype: float64, Predicted=1
# windspeed     11.2
# pressure     998.9
# Name: 654, dtype: float64, Predicted=1
# windspeed     15.971666
# pressure     958.395150
# Name: 6737, dtype: float64, Predicted=1
# windspeed     15.773668
# pressure     996.962625
# Name: 7069, dtype: float64, Predicted=1
# windspeed     12.097344
# pressure     996.074465
# Name: 9273, dtype: float64, Predicted=1
# windspeed     17.111846
# pressure     975.057115
# Name: 7309, dtype: float64, Predicted=1
# windspeed     16.752484
# pressure     974.147926
# Name: 9687, dtype: float64, Predicted=1
# windspeed     14.703909
# pressure     976.015104
# Name: 8168, dtype: float64, Predicted=1
# windspeed     17.149823
# pressure     964.973187
# Name: 6840, dtype: float64, Predicted=1
# windspeed     18.434286
# pressure     991.876122
# Name: 8409, dtype: float64, Predicted=1
# windspeed     17.115462
# pressure     994.872382
# Name: 11480, dtype: float64, Predicted=1
# windspeed     16.674860
# pressure     989.886588
# Name: 7056, dtype: float64, Predicted=1
# windspeed     15.890773
# pressure     986.317706
# Name: 9394, dtype: float64, Predicted=1
# windspeed      7.990480
# pressure     999.232245
# Name: 8735, dtype: float64, Predicted=1
# windspeed     16.517377
# pressure     974.428583
# Name: 10308, dtype: float64, Predicted=1
# windspeed     14.474070
# pressure     993.173806
# Name: 11630, dtype: float64, Predicted=1
# windspeed     17.043911
# pressure     982.115175
# Name: 10483, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     999.6
# Name: 2177, dtype: float64, Predicted=1
# windspeed     14.426530
# pressure     999.046148
# Name: 6156, dtype: float64, Predicted=1
# windspeed     17.123874
# pressure     994.660117
# Name: 6751, dtype: float64, Predicted=1
# windspeed     11.722237
# pressure     996.217266
# Name: 8986, dtype: float64, Predicted=1
# windspeed     17.194983
# pressure     975.856136
# Name: 6881, dtype: float64, Predicted=1
# windspeed     16.107977
# pressure     995.374417
# Name: 9964, dtype: float64, Predicted=1
# windspeed     16.806561
# pressure     994.027045
# Name: 6134, dtype: float64, Predicted=1
# windspeed     15.239971
# pressure     992.482890
# Name: 10356, dtype: float64, Predicted=1
# windspeed     14.211098
# pressure     999.445327
# Name: 10883, dtype: float64, Predicted=1
# windspeed     14.509046
# pressure     979.249844
# Name: 7808, dtype: float64, Predicted=1
# windspeed      5.7
# pressure     997.8
# Name: 4393, dtype: float64, Predicted=1
# windspeed     16.516862
# pressure     971.695313
# Name: 8165, dtype: float64, Predicted=1
# windspeed     16.104106
# pressure     984.507003
# Name: 8242, dtype: float64, Predicted=1
# windspeed     16.2
# pressure     991.5
# Name: 2060, dtype: float64, Predicted=1
# windspeed     12.2
# pressure     993.8
# Name: 4802, dtype: float64, Predicted=1
# windspeed     16.852936
# pressure     995.143412
# Name: 10064, dtype: float64, Predicted=1
# windspeed     15.485066
# pressure     984.897731
# Name: 8042, dtype: float64, Predicted=1
# windspeed     17.100639
# pressure     971.158449
# Name: 10238, dtype: float64, Predicted=1
# windspeed     15.664490
# pressure     976.088369
# Name: 11093, dtype: float64, Predicted=1
# windspeed     15.732376
# pressure     975.584876
# Name: 6284, dtype: float64, Predicted=1
# windspeed     16.771851
# pressure     968.541997
# Name: 7196, dtype: float64, Predicted=1
# windspeed     10.573413
# pressure     976.523066
# Name: 9929, dtype: float64, Predicted=1
# windspeed     14.601651
# pressure     977.712599
# Name: 7747, dtype: float64, Predicted=1
# windspeed     16.363628
# pressure     968.336132
# Name: 7571, dtype: float64, Predicted=1
# windspeed     11.832932
# pressure     996.091021
# Name: 8102, dtype: float64, Predicted=1
# windspeed     16.515499
# pressure     994.482001
# Name: 8391, dtype: float64, Predicted=1
# windspeed     14.189827
# pressure     999.491142
# Name: 8082, dtype: float64, Predicted=1
# windspeed      6.530306
# pressure     988.289852
# Name: 11586, dtype: float64, Predicted=1
# windspeed     13.543596
# pressure     992.680895
# Name: 11154, dtype: float64, Predicted=1
# windspeed     13.9
# pressure     998.4
# Name: 3059, dtype: float64, Predicted=1
# windspeed      9.529987
# pressure     983.149581
# Name: 10093, dtype: float64, Predicted=1
# windspeed     10.8
# pressure     994.5
# Name: 462, dtype: float64, Predicted=1
# windspeed      9.975973
# pressure     998.904386
# Name: 8171, dtype: float64, Predicted=1
# windspeed     16.319507
# pressure     987.818275
# Name: 9482, dtype: float64, Predicted=1
# windspeed     15.289656
# pressure     984.213794
# Name: 7578, dtype: float64, Predicted=1
# windspeed     11.584373
# pressure     987.018279
# Name: 9881, dtype: float64, Predicted=1
# windspeed      9.1
# pressure     996.9
# Name: 2529, dtype: float64, Predicted=1
# windspeed     14.842813
# pressure     998.871515
# Name: 10671, dtype: float64, Predicted=1
# windspeed     17.191475
# pressure     977.708633
# Name: 10863, dtype: float64, Predicted=1
# windspeed      4.3
# pressure     999.0
# Name: 1756, dtype: float64, Predicted=1
# windspeed     11.6
# pressure     998.0
# Name: 675, dtype: float64, Predicted=1
# windspeed     16.336595
# pressure     962.627645
# Name: 7347, dtype: float64, Predicted=1
# windspeed     11.438850
# pressure     996.563627
# Name: 11370, dtype: float64, Predicted=1
# windspeed     10.245852
# pressure     987.423462
# Name: 9453, dtype: float64, Predicted=1
# windspeed     14.0
# pressure     995.9
# Name: 5566, dtype: float64, Predicted=1
# windspeed     16.351730
# pressure     968.007735
# Name: 8539, dtype: float64, Predicted=1
# windspeed     16.540592
# pressure     969.590612
# Name: 6722, dtype: float64, Predicted=1
# windspeed     15.7
# pressure     997.5
# Name: 206, dtype: float64, Predicted=1
# windspeed      9.2
# pressure     995.7
# Name: 3839, dtype: float64, Predicted=1
# windspeed     15.530889
# pressure     977.079237
# Name: 7591, dtype: float64, Predicted=1
# windspeed     12.030939
# pressure     995.858373
# Name: 6248, dtype: float64, Predicted=1
# windspeed     11.491006
# pressure     996.555063
# Name: 8693, dtype: float64, Predicted=1
# windspeed     15.939312
# pressure     996.773119
# Name: 10347, dtype: float64, Predicted=1
# windspeed      8.137733
# pressure     999.373067
# Name: 8911, dtype: float64, Predicted=1
# windspeed     16.613277
# pressure     973.018805
# Name: 10286, dtype: float64, Predicted=1
# windspeed     15.904735
# pressure     968.468042
# Name: 8353, dtype: float64, Predicted=1
# windspeed      9.265223
# pressure     999.229760
# Name: 8582, dtype: float64, Predicted=1
# windspeed     10.164241
# pressure     998.151819
# Name: 11582, dtype: float64, Predicted=1
# windspeed     14.805473
# pressure     974.329155
# Name: 11058, dtype: float64, Predicted=1
# windspeed      4.8
# pressure     999.6
# Name: 3714, dtype: float64, Predicted=1
# windspeed     14.697592
# pressure     981.441785
# Name: 7529, dtype: float64, Predicted=1
# windspeed     16.347159
# pressure     988.786939
# Name: 8711, dtype: float64, Predicted=1
# windspeed     11.58917
# pressure     996.09087
# Name: 9813, dtype: float64, Predicted=1
# windspeed     15.748915
# pressure     968.921337
# Name: 8875, dtype: float64, Predicted=1
# windspeed      8.871395
# pressure     999.121454
# Name: 10604, dtype: float64, Predicted=1
# windspeed     16.129705
# pressure     959.967630
# Name: 10920, dtype: float64, Predicted=1
# windspeed      9.316804
# pressure     998.893885
# Name: 7356, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     999.5
# Name: 5274, dtype: float64, Predicted=1
# windspeed     14.613064
# pressure     979.917716
# Name: 8307, dtype: float64, Predicted=1
# windspeed     16.028815
# pressure     959.095289
# Name: 7919, dtype: float64, Predicted=1
# windspeed     16.656327
# pressure     995.494120
# Name: 7146, dtype: float64, Predicted=1
# windspeed     16.095574
# pressure     959.528807
# Name: 9718, dtype: float64, Predicted=1
# windspeed      7.278555
# pressure     989.362040
# Name: 6841, dtype: float64, Predicted=1
# windspeed     14.924179
# pressure     972.358629
# Name: 8860, dtype: float64, Predicted=1
# windspeed     11.308673
# pressure     987.101736
# Name: 11438, dtype: float64, Predicted=1
# windspeed      9.911158
# pressure     997.783100
# Name: 6520, dtype: float64, Predicted=1
# windspeed     16.479372
# pressure     971.530680
# Name: 11768, dtype: float64, Predicted=1
# windspeed     18.639183
# pressure     991.605365
# Name: 9105, dtype: float64, Predicted=1
# windspeed      9.209248
# pressure     999.383229
# Name: 7645, dtype: float64, Predicted=1
# windspeed     15.156278
# pressure     992.782048
# Name: 11050, dtype: float64, Predicted=1
# windspeed     14.720313
# pressure     991.048784
# Name: 9004, dtype: float64, Predicted=1
# windspeed     12.3
# pressure     999.0
# Name: 665, dtype: float64, Predicted=1
# windspeed     14.168680
# pressure     977.777381
# Name: 6546, dtype: float64, Predicted=1
# windspeed     15.5
# pressure     993.1
# Name: 5933, dtype: float64, Predicted=1
# windspeed     14.0
# pressure     993.9
# Name: 2290, dtype: float64, Predicted=1
# windspeed     17.118193
# pressure     970.017445
# Name: 6628, dtype: float64, Predicted=1
# windspeed      6.955060
# pressure     988.419617
# Name: 11533, dtype: float64, Predicted=1
# windspeed     15.262514
# pressure     996.726581
# Name: 10163, dtype: float64, Predicted=1
# windspeed     15.708598
# pressure     975.761231
# Name: 9689, dtype: float64, Predicted=1
# windspeed     11.158076
# pressure     991.417185
# Name: 8538, dtype: float64, Predicted=1
# windspeed     14.068661
# pressure     992.192796
# Name: 8097, dtype: float64, Predicted=1
# windspeed     15.191054
# pressure     998.133067
# Name: 11284, dtype: float64, Predicted=1
# windspeed     11.494589
# pressure     977.738934
# Name: 6966, dtype: float64, Predicted=1
# windspeed      7.2
# pressure     996.3
# Name: 2563, dtype: float64, Predicted=1
# windspeed      8.548136
# pressure     999.834863
# Name: 8210, dtype: float64, Predicted=1
# windspeed     14.308361
# pressure     995.976889
# Name: 8420, dtype: float64, Predicted=1
# windspeed     16.804079
# pressure     969.099087
# Name: 9740, dtype: float64, Predicted=1
# windspeed      8.8
# pressure     998.7
# Name: 768, dtype: float64, Predicted=1
# windspeed     12.236082
# pressure     993.854243
# Name: 8574, dtype: float64, Predicted=1
# windspeed      8.520805
# pressure     999.857288
# Name: 9071, dtype: float64, Predicted=1
# windspeed     11.344979
# pressure     996.753242
# Name: 7438, dtype: float64, Predicted=1
# windspeed     11.088545
# pressure     984.561866
# Name: 9725, dtype: float64, Predicted=1
# windspeed      5.306341
# pressure     994.210464
# Name: 6319, dtype: float64, Predicted=1
# windspeed     14.554079
# pressure     979.958819
# Name: 10769, dtype: float64, Predicted=1
# windspeed     15.345403
# pressure     997.769680
# Name: 11448, dtype: float64, Predicted=1
# windspeed      7.9
# pressure     995.7
# Name: 593, dtype: float64, Predicted=1
# windspeed     10.122092
# pressure     998.183431
# Name: 10300, dtype: float64, Predicted=1
# windspeed     14.836266
# pressure     992.824039
# Name: 7325, dtype: float64, Predicted=1
# windspeed      6.137571
# pressure     989.283917
# Name: 8598, dtype: float64, Predicted=1
# windspeed     15.937614
# pressure     996.852965
# Name: 8935, dtype: float64, Predicted=1
# windspeed     15.779062
# pressure     972.436218
# Name: 10246, dtype: float64, Predicted=1
# windspeed      9.693426
# pressure     998.768618
# Name: 11781, dtype: float64, Predicted=1
# windspeed      6.5
# pressure     998.9
# Name: 3269, dtype: float64, Predicted=1
# windspeed      5.0
# pressure     996.0
# Name: 2633, dtype: float64, Predicted=1
# windspeed      6.028815
# pressure     988.700000
# Name: 5601, dtype: float64, Predicted=1
# windspeed      8.354273
# pressure     999.798143
# Name: 9256, dtype: float64, Predicted=1
# windspeed     10.444226
# pressure     997.941831
# Name: 9072, dtype: float64, Predicted=1
# windspeed     15.370866
# pressure     983.387649
# Name: 10451, dtype: float64, Predicted=1
# windspeed     10.393534
# pressure     997.994181
# Name: 6575, dtype: float64, Predicted=1
# windspeed     14.832188
# pressure     980.665260
# Name: 9017, dtype: float64, Predicted=1
# windspeed     16.374681
# pressure     968.641192
# Name: 11444, dtype: float64, Predicted=1
# windspeed     14.699435
# pressure     999.034369
# Name: 6903, dtype: float64, Predicted=1
# windspeed     13.929917
# pressure     979.695183
# Name: 7864, dtype: float64, Predicted=1
# windspeed      6.175687
# pressure     989.488564
# Name: 9590, dtype: float64, Predicted=1
# windspeed     12.349172
# pressure     992.392133
# Name: 9422, dtype: float64, Predicted=1
# windspeed     14.066191
# pressure     992.197131
# Name: 10446, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     996.9
# Name: 3595, dtype: float64, Predicted=1
# windspeed      9.566215
# pressure     997.935981
# Name: 11335, dtype: float64, Predicted=1
# windspeed     15.201073
# pressure     973.541605
# Name: 10407, dtype: float64, Predicted=1
# windspeed      9.7
# pressure     993.9
# Name: 4448, dtype: float64, Predicted=1
# windspeed     15.953812
# pressure     991.615264
# Name: 9825, dtype: float64, Predicted=1
# windspeed     16.651076
# pressure     968.474187
# Name: 8368, dtype: float64, Predicted=1
# windspeed      3.6
# pressure     997.6
# Name: 5905, dtype: float64, Predicted=1
# windspeed     16.574854
# pressure     994.354161
# Name: 10358, dtype: float64, Predicted=1
# windspeed     10.5
# pressure     997.9
# Name: 2872, dtype: float64, Predicted=1
# windspeed     14.512928
# pressure     979.533591
# Name: 8853, dtype: float64, Predicted=1
# windspeed      9.0
# pressure     995.7
# Name: 5463, dtype: float64, Predicted=1
# windspeed     17.291056
# pressure     978.516345
# Name: 11253, dtype: float64, Predicted=1
# windspeed     15.603523
# pressure     976.540541
# Name: 10226, dtype: float64, Predicted=1
# windspeed     16.976730
# pressure     979.212526
# Name: 8621, dtype: float64, Predicted=1
# windspeed     15.763149
# pressure     991.884972
# Name: 6674, dtype: float64, Predicted=1
# windspeed      5.6
# pressure     995.2
# Name: 2984, dtype: float64, Predicted=1
# windspeed     15.935113
# pressure     986.472897
# Name: 11368, dtype: float64, Predicted=1
# windspeed      7.7
# pressure     996.7
# Name: 237, dtype: float64, Predicted=1
# windspeed      3.0
# pressure     996.8
# Name: 179, dtype: float64, Predicted=0
# windspeed     15.598130
# pressure     984.428279
# Name: 7424, dtype: float64, Predicted=1
# windspeed     16.550754
# pressure     970.881911
# Name: 6116, dtype: float64, Predicted=1
# windspeed      9.5
# pressure     996.9
# Name: 5761, dtype: float64, Predicted=1
# windspeed     11.812745
# pressure     995.719509
# Name: 10474, dtype: float64, Predicted=1
# windspeed      9.265011
# pressure     999.220542
# Name: 6339, dtype: float64, Predicted=1
# windspeed     12.075733
# pressure     995.809921
# Name: 10880, dtype: float64, Predicted=1
# windspeed     16.663419
# pressure     973.425510
# Name: 10442, dtype: float64, Predicted=1
# windspeed     14.851703
# pressure     973.561735
# Name: 7813, dtype: float64, Predicted=1
# windspeed     11.309660
# pressure     996.721527
# Name: 7854, dtype: float64, Predicted=1
# windspeed      9.244291
# pressure     999.698616
# Name: 11385, dtype: float64, Predicted=1
# windspeed     16.862392
# pressure     970.107070
# Name: 10862, dtype: float64, Predicted=1
# windspeed     14.978372
# pressure     983.124301
# Name: 10764, dtype: float64, Predicted=1
# windspeed     18.826222
# pressure     991.358206
# Name: 7165, dtype: float64, Predicted=1
# windspeed      4.8
# pressure     995.6
# Name: 4534, dtype: float64, Predicted=1
# windspeed     16.5
# pressure     994.9
# Name: 5976, dtype: float64, Predicted=1
# windspeed      8.085595
# pressure     988.077393
# Name: 6252, dtype: float64, Predicted=1
# windspeed     11.192394
# pressure     996.749922
# Name: 7597, dtype: float64, Predicted=1
# windspeed     16.660103
# pressure     985.041714
# Name: 6878, dtype: float64, Predicted=1
# windspeed     16.330818
# pressure     994.788372
# Name: 6975, dtype: float64, Predicted=1
# windspeed     12.7
# pressure     998.0
# Name: 137, dtype: float64, Predicted=1
# windspeed     15.838480
# pressure     981.281542
# Name: 7731, dtype: float64, Predicted=1
# windspeed      6.8
# pressure     999.5
# Name: 2162, dtype: float64, Predicted=1
# windspeed      8.114023
# pressure     999.394324
# Name: 10742, dtype: float64, Predicted=1

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.52

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_pred, y_test)
names = np.unique(y_pred)
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False,xticklabels=names, yticklabels=names)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.show()

# %%
df_b8_logit = df_b8_init[keep_col]
y2=df_b8_init['hurrthreat']

# %%
y_pred2 = logreg.predict(df_b8_logit)
for i in range(len(df_b8_logit)):
    if(df_b8_logit.iloc[i]['pressure']<1000):
        print("%s, Predicted=%s" % (df_b8_logit.iloc[i], y_pred2[i]))
# Out:
# windspeed      2.6
# pressure     999.6
# Name: 152, dtype: float64, Predicted=0
# windspeed      2.5
# pressure     999.0
# Name: 153, dtype: float64, Predicted=0
# windspeed      3.7
# pressure     998.6
# Name: 154, dtype: float64, Predicted=1
# windspeed      4.3
# pressure     998.1
# Name: 155, dtype: float64, Predicted=1
# windspeed      4.9
# pressure     997.8
# Name: 156, dtype: float64, Predicted=1
# windspeed      5.0
# pressure     997.3
# Name: 157, dtype: float64, Predicted=1
# windspeed      5.4
# pressure     997.0
# Name: 158, dtype: float64, Predicted=1
# windspeed      6.7
# pressure     996.5
# Name: 159, dtype: float64, Predicted=1
# windspeed      6.9
# pressure     995.7
# Name: 160, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     994.9
# Name: 161, dtype: float64, Predicted=1
# windspeed      4.4
# pressure     994.2
# Name: 162, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     993.7
# Name: 163, dtype: float64, Predicted=1
# windspeed      5.4
# pressure     994.0
# Name: 164, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     994.3
# Name: 165, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     994.5
# Name: 166, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     994.9
# Name: 167, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     995.4
# Name: 168, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     995.8
# Name: 169, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     996.2
# Name: 170, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     996.0
# Name: 171, dtype: float64, Predicted=1
# windspeed      8.6
# pressure     996.1
# Name: 172, dtype: float64, Predicted=1
# windspeed      7.0
# pressure     996.3
# Name: 173, dtype: float64, Predicted=1
# windspeed      6.4
# pressure     996.4
# Name: 174, dtype: float64, Predicted=1
# windspeed      4.9
# pressure     996.5
# Name: 175, dtype: float64, Predicted=1
# windspeed      4.6
# pressure     996.4
# Name: 176, dtype: float64, Predicted=1
# windspeed      3.3
# pressure     996.4
# Name: 177, dtype: float64, Predicted=1
# windspeed      2.9
# pressure     996.4
# Name: 178, dtype: float64, Predicted=0
# windspeed      2.5
# pressure     996.6
# Name: 179, dtype: float64, Predicted=0
# windspeed      2.6
# pressure     996.5
# Name: 180, dtype: float64, Predicted=0
# windspeed      1.8
# pressure     996.7
# Name: 181, dtype: float64, Predicted=0
# windspeed      2.5
# pressure     996.7
# Name: 182, dtype: float64, Predicted=0
# windspeed      1.5
# pressure     996.9
# Name: 183, dtype: float64, Predicted=0
# windspeed      0.7
# pressure     996.4
# Name: 184, dtype: float64, Predicted=0
# windspeed      1.9
# pressure     995.9
# Name: 185, dtype: float64, Predicted=0
# windspeed      1.6
# pressure     995.6
# Name: 186, dtype: float64, Predicted=0
# windspeed      3.8
# pressure     995.1
# Name: 187, dtype: float64, Predicted=1
# windspeed      4.2
# pressure     995.1
# Name: 188, dtype: float64, Predicted=1
# windspeed      5.6
# pressure     995.6
# Name: 189, dtype: float64, Predicted=1
# windspeed      9.4
# pressure     995.8
# Name: 190, dtype: float64, Predicted=1
# windspeed      8.7
# pressure     996.3
# Name: 191, dtype: float64, Predicted=1
# windspeed      8.6
# pressure     997.2
# Name: 192, dtype: float64, Predicted=1
# windspeed      9.2
# pressure     997.8
# Name: 193, dtype: float64, Predicted=1
# windspeed     10.5
# pressure     998.0
# Name: 194, dtype: float64, Predicted=1
# windspeed     11.0
# pressure     997.9
# Name: 195, dtype: float64, Predicted=1
# windspeed     11.1
# pressure     997.9
# Name: 196, dtype: float64, Predicted=1
# windspeed     11.8
# pressure     998.0
# Name: 197, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     998.6
# Name: 198, dtype: float64, Predicted=1
# windspeed     12.8
# pressure     999.7
# Name: 199, dtype: float64, Predicted=1
# windspeed      1.5
# pressure     998.6
# Name: 490, dtype: float64, Predicted=0
# windspeed      3.0
# pressure     997.8
# Name: 491, dtype: float64, Predicted=0
# windspeed     10.3
# pressure     997.9
# Name: 492, dtype: float64, Predicted=1
# windspeed      8.0
# pressure     998.4
# Name: 493, dtype: float64, Predicted=1
# windspeed     13.6
# pressure     999.2
# Name: 494, dtype: float64, Predicted=1
# windspeed     14.6
# pressure     997.6
# Name: 624, dtype: float64, Predicted=1
# windspeed     14.7
# pressure     996.5
# Name: 625, dtype: float64, Predicted=1
# windspeed     12.7
# pressure     997.0
# Name: 626, dtype: float64, Predicted=1
# windspeed     13.8
# pressure     995.6
# Name: 627, dtype: float64, Predicted=1
# windspeed     13.2
# pressure     998.2
# Name: 628, dtype: float64, Predicted=1
# windspeed     13.8
# pressure     997.9
# Name: 629, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     999.1
# Name: 630, dtype: float64, Predicted=1
# windspeed      5.0
# pressure     999.3
# Name: 861, dtype: float64, Predicted=1
# windspeed      3.4
# pressure     997.4
# Name: 862, dtype: float64, Predicted=1
# windspeed      6.5
# pressure     995.6
# Name: 863, dtype: float64, Predicted=1
# windspeed      8.8
# pressure     993.7
# Name: 864, dtype: float64, Predicted=1
# windspeed     11.4
# pressure     993.7
# Name: 865, dtype: float64, Predicted=1
# windspeed     11.0
# pressure     994.8
# Name: 866, dtype: float64, Predicted=1
# windspeed     11.7
# pressure     995.8
# Name: 867, dtype: float64, Predicted=1
# windspeed     12.6
# pressure     997.2
# Name: 868, dtype: float64, Predicted=1
# windspeed     12.4
# pressure     998.1
# Name: 869, dtype: float64, Predicted=1
# windspeed     12.9
# pressure     999.3
# Name: 870, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     999.8
# Name: 1070, dtype: float64, Predicted=1
# windspeed      5.9
# pressure     998.9
# Name: 1071, dtype: float64, Predicted=1
# windspeed      7.4
# pressure     997.9
# Name: 1072, dtype: float64, Predicted=1
# windspeed      8.5
# pressure     997.1
# Name: 1073, dtype: float64, Predicted=1
# windspeed      7.7
# pressure     996.3
# Name: 1074, dtype: float64, Predicted=1
# windspeed      9.0
# pressure     996.2
# Name: 1075, dtype: float64, Predicted=1
# windspeed      9.0
# pressure     997.4
# Name: 1076, dtype: float64, Predicted=1
# windspeed     14.2
# pressure     998.4
# Name: 1077, dtype: float64, Predicted=1
# windspeed     11.6
# pressure     998.3
# Name: 1330, dtype: float64, Predicted=1
# windspeed     16.4
# pressure     994.9
# Name: 1331, dtype: float64, Predicted=1
# windspeed     15.0
# pressure     993.1
# Name: 1332, dtype: float64, Predicted=1
# windspeed     14.5
# pressure     991.1
# Name: 1333, dtype: float64, Predicted=1
# windspeed     14.1
# pressure     989.6
# Name: 1334, dtype: float64, Predicted=1
# windspeed     13.0
# pressure     988.3
# Name: 1335, dtype: float64, Predicted=1
# windspeed      6.1
# pressure     990.1
# Name: 1336, dtype: float64, Predicted=1
# windspeed      6.0
# pressure     990.6
# Name: 1337, dtype: float64, Predicted=1
# windspeed     15.7
# pressure     992.0
# Name: 1338, dtype: float64, Predicted=1
# windspeed     17.0
# pressure     995.8
# Name: 1339, dtype: float64, Predicted=1
# windspeed     12.1
# pressure     998.6
# Name: 1406, dtype: float64, Predicted=1
# windspeed     11.0
# pressure     997.7
# Name: 1407, dtype: float64, Predicted=1
# windspeed     10.7
# pressure     998.2
# Name: 1408, dtype: float64, Predicted=1
# windspeed      9.4
# pressure     998.9
# Name: 1409, dtype: float64, Predicted=1
# windspeed     12.2
# pressure     999.5
# Name: 1561, dtype: float64, Predicted=1
# windspeed     11.0
# pressure     998.1
# Name: 1562, dtype: float64, Predicted=1
# windspeed     10.1
# pressure     997.1
# Name: 1563, dtype: float64, Predicted=1
# windspeed      7.6
# pressure     996.6
# Name: 1564, dtype: float64, Predicted=1
# windspeed      8.2
# pressure     996.2
# Name: 1565, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     998.2
# Name: 1566, dtype: float64, Predicted=1
# windspeed      9.2
# pressure     999.4
# Name: 1969, dtype: float64, Predicted=1
# windspeed      9.7
# pressure     999.1
# Name: 1970, dtype: float64, Predicted=1
# windspeed      9.2
# pressure     999.7
# Name: 1971, dtype: float64, Predicted=1
# windspeed     10.5
# pressure     999.8
# Name: 1973, dtype: float64, Predicted=1
# windspeed      9.7
# pressure     999.7
# Name: 2161, dtype: float64, Predicted=1
# windspeed      9.8
# pressure     997.9
# Name: 2162, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     997.5
# Name: 2163, dtype: float64, Predicted=1
# windspeed      7.5
# pressure     996.6
# Name: 2164, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     995.8
# Name: 2165, dtype: float64, Predicted=1
# windspeed      8.1
# pressure     995.1
# Name: 2166, dtype: float64, Predicted=1
# windspeed      7.1
# pressure     995.1
# Name: 2167, dtype: float64, Predicted=1
# windspeed      6.8
# pressure     995.0
# Name: 2168, dtype: float64, Predicted=1
# windspeed      7.2
# pressure     994.8
# Name: 2169, dtype: float64, Predicted=1
# windspeed      6.6
# pressure     994.9
# Name: 2170, dtype: float64, Predicted=1
# windspeed      7.4
# pressure     994.4
# Name: 2171, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     993.8
# Name: 2172, dtype: float64, Predicted=1
# windspeed      8.6
# pressure     993.2
# Name: 2173, dtype: float64, Predicted=1
# windspeed      7.7
# pressure     992.6
# Name: 2174, dtype: float64, Predicted=1
# windspeed      8.5
# pressure     992.6
# Name: 2175, dtype: float64, Predicted=1
# windspeed      8.2
# pressure     992.8
# Name: 2176, dtype: float64, Predicted=1
# windspeed      9.3
# pressure     993.6
# Name: 2177, dtype: float64, Predicted=1
# windspeed      4.4
# pressure     994.6
# Name: 2178, dtype: float64, Predicted=1
# windspeed      4.6
# pressure     995.2
# Name: 2179, dtype: float64, Predicted=1
# windspeed      6.8
# pressure     995.7
# Name: 2180, dtype: float64, Predicted=1
# windspeed     10.5
# pressure     996.3
# Name: 2181, dtype: float64, Predicted=1
# windspeed      8.9
# pressure     996.9
# Name: 2182, dtype: float64, Predicted=1
# windspeed      9.6
# pressure     997.2
# Name: 2183, dtype: float64, Predicted=1
# windspeed     10.4
# pressure     997.2
# Name: 2184, dtype: float64, Predicted=1
# windspeed     10.2
# pressure     997.2
# Name: 2185, dtype: float64, Predicted=1
# windspeed     10.7
# pressure     997.2
# Name: 2186, dtype: float64, Predicted=1
# windspeed     10.6
# pressure     997.3
# Name: 2187, dtype: float64, Predicted=1
# windspeed      9.8
# pressure     997.8
# Name: 2188, dtype: float64, Predicted=1
# windspeed      9.4
# pressure     998.6
# Name: 2189, dtype: float64, Predicted=1
# windspeed     10.6
# pressure     999.1
# Name: 2190, dtype: float64, Predicted=1
# windspeed      5.3
# pressure     999.7
# Name: 2196, dtype: float64, Predicted=1
# windspeed      5.7
# pressure     999.2
# Name: 2197, dtype: float64, Predicted=1
# windspeed      5.9
# pressure     998.9
# Name: 2198, dtype: float64, Predicted=1
# windspeed      6.0
# pressure     998.7
# Name: 2199, dtype: float64, Predicted=1
# windspeed      6.4
# pressure     998.8
# Name: 2200, dtype: float64, Predicted=1
# windspeed      6.3
# pressure     999.4
# Name: 2201, dtype: float64, Predicted=1
# windspeed      8.6
# pressure     999.6
# Name: 2249, dtype: float64, Predicted=1
# windspeed     10.1
# pressure     999.0
# Name: 2250, dtype: float64, Predicted=1
# windspeed      9.8
# pressure     998.5
# Name: 2251, dtype: float64, Predicted=1
# windspeed      9.9
# pressure     997.8
# Name: 2252, dtype: float64, Predicted=1
# windspeed     10.4
# pressure     997.6
# Name: 2253, dtype: float64, Predicted=1
# windspeed     12.9
# pressure     996.7
# Name: 2254, dtype: float64, Predicted=1
# windspeed     12.9
# pressure     996.5
# Name: 2255, dtype: float64, Predicted=1
# windspeed     12.4
# pressure     996.2
# Name: 2256, dtype: float64, Predicted=1
# windspeed     12.8
# pressure     995.9
# Name: 2257, dtype: float64, Predicted=1
# windspeed     12.7
# pressure     994.8
# Name: 2258, dtype: float64, Predicted=1
# windspeed     12.1
# pressure     994.4
# Name: 2259, dtype: float64, Predicted=1
# windspeed     14.1
# pressure     993.6
# Name: 2260, dtype: float64, Predicted=1
# windspeed     13.4
# pressure     992.9
# Name: 2261, dtype: float64, Predicted=1
# windspeed     13.6
# pressure     991.7
# Name: 2262, dtype: float64, Predicted=1
# windspeed     12.4
# pressure     991.6
# Name: 2263, dtype: float64, Predicted=1
# windspeed     14.3
# pressure     990.5
# Name: 2264, dtype: float64, Predicted=1
# windspeed     12.7
# pressure     989.8
# Name: 2265, dtype: float64, Predicted=1
# windspeed     12.9
# pressure     990.2
# Name: 2266, dtype: float64, Predicted=1
# windspeed     14.0
# pressure     989.4
# Name: 2267, dtype: float64, Predicted=1
# windspeed      9.6
# pressure     992.2
# Name: 2268, dtype: float64, Predicted=1
# windspeed     11.4
# pressure     993.8
# Name: 2269, dtype: float64, Predicted=1
# windspeed     13.2
# pressure     995.4
# Name: 2270, dtype: float64, Predicted=1
# windspeed      9.0
# pressure     996.1
# Name: 2271, dtype: float64, Predicted=1
# windspeed     10.9
# pressure     998.0
# Name: 2272, dtype: float64, Predicted=1
# windspeed     14.5
# pressure     999.6
# Name: 2543, dtype: float64, Predicted=1
# windspeed     14.5
# pressure     997.1
# Name: 2544, dtype: float64, Predicted=1
# windspeed     12.4
# pressure     996.6
# Name: 2545, dtype: float64, Predicted=1
# windspeed      5.6
# pressure     997.5
# Name: 2546, dtype: float64, Predicted=1
# windspeed      5.1
# pressure     998.0
# Name: 2547, dtype: float64, Predicted=1
# windspeed      5.3
# pressure     998.7
# Name: 2548, dtype: float64, Predicted=1
# windspeed      7.7
# pressure     999.7
# Name: 2549, dtype: float64, Predicted=1
# windspeed      2.7
# pressure     999.9
# Name: 5256, dtype: float64, Predicted=0
# windspeed      3.0
# pressure     999.4
# Name: 5257, dtype: float64, Predicted=0
# windspeed      3.8
# pressure     998.9
# Name: 5258, dtype: float64, Predicted=1
# windspeed      4.3
# pressure     999.0
# Name: 5259, dtype: float64, Predicted=1
# windspeed      5.6
# pressure     999.3
# Name: 5260, dtype: float64, Predicted=1
# windspeed      5.9
# pressure     999.7
# Name: 5261, dtype: float64, Predicted=1
# windspeed      5.1
# pressure     999.9
# Name: 5262, dtype: float64, Predicted=1
# windspeed      8.1
# pressure     999.7
# Name: 5296, dtype: float64, Predicted=1
# windspeed      8.0
# pressure     998.6
# Name: 5297, dtype: float64, Predicted=1
# windspeed      7.3
# pressure     998.7
# Name: 5298, dtype: float64, Predicted=1
# windspeed      5.9
# pressure     999.0
# Name: 5299, dtype: float64, Predicted=1
# windspeed      2.3
# pressure     999.3
# Name: 5300, dtype: float64, Predicted=0
# windspeed      3.3
# pressure     999.3
# Name: 5301, dtype: float64, Predicted=0
# windspeed      3.9
# pressure     999.4
# Name: 5302, dtype: float64, Predicted=1
# windspeed      6.1
# pressure     999.3
# Name: 5303, dtype: float64, Predicted=1
# windspeed      6.3
# pressure     999.3
# Name: 5304, dtype: float64, Predicted=1
# windspeed      7.7
# pressure     999.2
# Name: 5305, dtype: float64, Predicted=1
# windspeed      9.4
# pressure     999.0
# Name: 5306, dtype: float64, Predicted=1
# windspeed      8.8
# pressure     999.6
# Name: 5307, dtype: float64, Predicted=1
# windspeed     14.2
# pressure     999.3
# Name: 5733, dtype: float64, Predicted=1
# windspeed     15.4
# pressure     997.2
# Name: 5734, dtype: float64, Predicted=1
# windspeed     18.7
# pressure     991.2
# Name: 5736, dtype: float64, Predicted=1
# windspeed     16.3
# pressure     989.6
# Name: 5737, dtype: float64, Predicted=1
# windspeed     15.8
# pressure     986.2
# Name: 5738, dtype: float64, Predicted=1
# windspeed     17.7
# pressure     983.1
# Name: 5739, dtype: float64, Predicted=1
# windspeed     15.6
# pressure     980.2
# Name: 5740, dtype: float64, Predicted=1
# windspeed     17.8
# pressure     976.4
# Name: 5741, dtype: float64, Predicted=1
# windspeed     19.5
# pressure     972.2
# Name: 5742, dtype: float64, Predicted=1
# windspeed     19.7
# pressure     968.2
# Name: 5743, dtype: float64, Predicted=1
# windspeed     20.0
# pressure     968.0
# Name: 5744, dtype: float64, Predicted=1
# windspeed     15.7
# pressure     972.0
# Name: 5745, dtype: float64, Predicted=1
# windspeed     13.1
# pressure     975.7
# Name: 5746, dtype: float64, Predicted=1
# windspeed     12.1
# pressure     978.6
# Name: 5747, dtype: float64, Predicted=1
# windspeed     12.1
# pressure     981.1
# Name: 5748, dtype: float64, Predicted=1
# windspeed     12.5
# pressure     983.4
# Name: 5749, dtype: float64, Predicted=1
# windspeed     15.9
# pressure     986.5
# Name: 5750, dtype: float64, Predicted=1
# windspeed     15.7
# pressure     988.6
# Name: 5751, dtype: float64, Predicted=1
# windspeed     18.1
# pressure     990.5
# Name: 5752, dtype: float64, Predicted=1
# windspeed     16.2
# pressure     994.1
# Name: 5753, dtype: float64, Predicted=1
# windspeed     18.2
# pressure     996.7
# Name: 5754, dtype: float64, Predicted=1
# windspeed     15.2
# pressure     999.7
# Name: 5755, dtype: float64, Predicted=1
# windspeed      5.9
# pressure     999.7
# Name: 6069, dtype: float64, Predicted=1
# windspeed      6.1
# pressure     999.4
# Name: 6070, dtype: float64, Predicted=1
# windspeed      5.5
# pressure     997.9
# Name: 6071, dtype: float64, Predicted=1
# windspeed      6.0
# pressure     997.0
# Name: 6072, dtype: float64, Predicted=1
# windspeed      7.9
# pressure     995.7
# Name: 6073, dtype: float64, Predicted=1
# windspeed      8.2
# pressure     995.1
# Name: 6074, dtype: float64, Predicted=1
# windspeed      9.4
# pressure     994.7
# Name: 6075, dtype: float64, Predicted=1
# windspeed      9.3
# pressure     995.6
# Name: 6076, dtype: float64, Predicted=1
# windspeed      8.7
# pressure     996.2
# Name: 6077, dtype: float64, Predicted=1
# windspeed     11.1
# pressure     997.0
# Name: 6078, dtype: float64, Predicted=1
# windspeed      9.8
# pressure     998.2
# Name: 6079, dtype: float64, Predicted=1
# windspeed      9.2
# pressure     999.2
# Name: 6080, dtype: float64, Predicted=1
# windspeed     11.5
# pressure     999.8
# Name: 6081, dtype: float64, Predicted=1
# windspeed     15.6
# pressure     999.2
# Name: 6193, dtype: float64, Predicted=1
# windspeed     13.3
# pressure     999.3
# Name: 6194, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     999.1
# Name: 6195, dtype: float64, Predicted=1
# windspeed      9.9
# pressure     998.9
# Name: 6196, dtype: float64, Predicted=1
# windspeed     10.4
# pressure     998.8
# Name: 6197, dtype: float64, Predicted=1
# windspeed     10.4
# pressure     998.0
# Name: 6198, dtype: float64, Predicted=1
# windspeed      8.4
# pressure     998.1
# Name: 6199, dtype: float64, Predicted=1
# windspeed      6.4
# pressure     997.1
# Name: 6200, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     995.8
# Name: 6201, dtype: float64, Predicted=1
# windspeed     10.0
# pressure     994.7
# Name: 6202, dtype: float64, Predicted=1
# windspeed     10.2
# pressure     994.0
# Name: 6203, dtype: float64, Predicted=1
# windspeed     10.2
# pressure     994.4
# Name: 6204, dtype: float64, Predicted=1
# windspeed      8.2
# pressure     994.5
# Name: 6205, dtype: float64, Predicted=1
# windspeed      9.6
# pressure     994.7
# Name: 6206, dtype: float64, Predicted=1
# windspeed      7.8
# pressure     994.1
# Name: 6207, dtype: float64, Predicted=1
# windspeed      8.5
# pressure     994.1
# Name: 6208, dtype: float64, Predicted=1
# windspeed     10.2
# pressure     994.4
# Name: 6209, dtype: float64, Predicted=1
# windspeed     10.7
# pressure     995.1
# Name: 6210, dtype: float64, Predicted=1
# windspeed     13.7
# pressure     996.1
# Name: 6211, dtype: float64, Predicted=1
# windspeed     14.2
# pressure     997.0
# Name: 6212, dtype: float64, Predicted=1
# windspeed     13.1
# pressure     997.9
# Name: 6213, dtype: float64, Predicted=1
# windspeed     11.6
# pressure     998.5
# Name: 6214, dtype: float64, Predicted=1
# windspeed     11.4
# pressure     998.7
# Name: 6215, dtype: float64, Predicted=1
# windspeed     11.4
# pressure     998.8
# Name: 6216, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     999.2
# Name: 6217, dtype: float64, Predicted=1
# windspeed     12.7
# pressure     999.6
# Name: 6218, dtype: float64, Predicted=1
# windspeed      3.5
# pressure     999.7
# Name: 7371, dtype: float64, Predicted=0
# windspeed      3.4
# pressure     998.2
# Name: 7372, dtype: float64, Predicted=0
# windspeed      2.8
# pressure     996.7
# Name: 7373, dtype: float64, Predicted=0
# windspeed      1.5
# pressure     995.6
# Name: 7374, dtype: float64, Predicted=0
# windspeed     13.0
# pressure     993.3
# Name: 7375, dtype: float64, Predicted=1
# windspeed     16.4
# pressure     994.4
# Name: 7376, dtype: float64, Predicted=1
# windspeed     15.0
# pressure     994.6
# Name: 7377, dtype: float64, Predicted=1
# windspeed      6.202014
# pressure     999.200000
# Name: 7378, dtype: float64, Predicted=1
# windspeed     13.3
# pressure     998.9
# Name: 7850, dtype: float64, Predicted=1
# windspeed     15.3
# pressure     996.1
# Name: 7851, dtype: float64, Predicted=1
# windspeed     16.6
# pressure     993.5
# Name: 7852, dtype: float64, Predicted=1
# windspeed     16.6
# pressure     993.0
# Name: 7853, dtype: float64, Predicted=1
# windspeed     11.8
# pressure     994.2
# Name: 7854, dtype: float64, Predicted=1
# windspeed      9.1
# pressure     995.1
# Name: 7855, dtype: float64, Predicted=1
# windspeed     10.8
# pressure     995.1
# Name: 7856, dtype: float64, Predicted=1
# windspeed      9.9
# pressure     995.6
# Name: 7857, dtype: float64, Predicted=1
# windspeed      8.3
# pressure     996.1
# Name: 7858, dtype: float64, Predicted=1
# windspeed      8.7
# pressure     996.5
# Name: 7859, dtype: float64, Predicted=1
# windspeed      7.2
# pressure     996.4
# Name: 7860, dtype: float64, Predicted=1
# windspeed     11.2
# pressure     996.2
# Name: 7861, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     997.0
# Name: 7862, dtype: float64, Predicted=1
# windspeed     11.7
# pressure     997.4
# Name: 7863, dtype: float64, Predicted=1
# windspeed     11.9
# pressure     998.0
# Name: 7864, dtype: float64, Predicted=1
# windspeed     12.6
# pressure     998.4
# Name: 7865, dtype: float64, Predicted=1
# windspeed     12.3
# pressure     999.1
# Name: 7866, dtype: float64, Predicted=1
# windspeed     13.6
# pressure     999.3
# Name: 7867, dtype: float64, Predicted=1
# windspeed     13.9
# pressure     999.2
# Name: 7868, dtype: float64, Predicted=1
# windspeed     15.1
# pressure     999.7
# Name: 7869, dtype: float64, Predicted=1
